# %%
import json
# Provided CMIP data
cmip_data = json.load(open('../../MIP_grid_label.json'))['grid_label']

print(cmip_data)

# Helper function to generate the short name
def generate_short_name(acronym):
    parts = []
    if 'gn' in acronym:
        parts.append('Grid Native')
    elif 'gr' in acronym:
        parts.append('Regridded')

    if 'a' in acronym:
        parts.append('Antarctica')
    if 'g' in acronym:
        parts.append('Greenland')
    if 'z' in acronym:
        parts.append('Zonal Mean')

    if '1' in acronym or '2' in acronym or '3' in acronym or '4' in acronym or '5' in acronym or '6' in acronym or '7' in acronym or '8' in acronym or '9' in acronym:
        parts.append(f"Alternate {acronym[-1]}")

    return ' '.join(parts) if parts else 'Global Mean'

# Helper function to determine the region
def determine_region(acronym):
    if 'a' in acronym:
        return 'Antarctica'
    elif 'g' in acronym:
        return 'Greenland'
    else:
        return 'Global'

# Constructing the full data structure
label_data = {}
for acronym, description in cmip_data.items():
    label_data[acronym] = {
        'short_name': generate_short_name(acronym),
        'region': determine_region(acronym),
        'full_description': description
    }
# Out:
# {'gm': 'global mean data', 'gn': "data reported on a model's native grid", 'gna': 'data reported on a native grid in the region of Antarctica', 'gng': 'data reported on a native grid in the region of Greenland', 'gnz': "zonal mean data reported on a model's native latitude grid", 'gr': "regridded data reported on the data provider's preferred target grid", 'gr1': 'regridded data reported on a grid other than the native grid and other than the preferred target grid', 'gr1a': 'regridded data reported in the region of Antarctica on a grid other than the native grid and other than the preferred target grid', 'gr1g': 'regridded data reported in the region of Greenland on a grid other than the native grid and other than the preferred target grid', 'gr1z': 'regridded zonal mean data reported on a grid other than the native latitude grid and other than the preferred latitude target grid', 'gr2': 'regridded data reported on a grid other than the native grid and other than the preferred target grid', 'gr2a': 'regridded data reported in the region of Antarctica on a grid other than the native grid and other than the preferred target grid', 'gr2g': 'regridded data reported in the region of Greenland on a grid other than the native grid and other than the preferred target grid', 'gr2z': 'regridded zonal mean data reported on a grid other than the native latitude grid and other than the preferred latitude target grid', 'gr3': 'regridded data reported on a grid other than the native grid and other than the preferred target grid', 'gr3a': 'regridded data reported in the region of Antarctica on a grid other than the native grid and other than the preferred target grid', 'gr3g': 'regridded data reported in the region of Greenland on a grid other than the native grid and other than the preferred target grid', 'gr3z': 'regridded zonal mean data reported on a grid other than the native latitude grid and other than the preferred latitude target grid', 'gr4': 'regridded data reported on a grid other than the native grid and other than the preferred target grid', 'gr4a': 'regridded data reported in the region of Antarctica on a grid other than the native grid and other than the preferred target grid', 'gr4g': 'regridded data reported in the region of Greenland on a grid other than the native grid and other than the preferred target grid', 'gr4z': 'regridded zonal mean data reported on a grid other than the native latitude grid and other than the preferred latitude target grid', 'gr5': 'regridded data reported on a grid other than the native grid and other than the preferred target grid', 'gr5a': 'regridded data reported in the region of Antarctica on a grid other than the native grid and other than the preferred target grid', 'gr5g': 'regridded data reported in the region of Greenland on a grid other than the native grid and other than the preferred target grid', 'gr5z': 'regridded zonal mean data reported on a grid other than the native latitude grid and other than the preferred latitude target grid', 'gr6': 'regridded data reported on a grid other than the native grid and other than the preferred target grid', 'gr6a': 'regridded data reported in the region of Antarctica on a grid other than the native grid and other than the preferred target grid', 'gr6g': 'regridded data reported in the region of Greenland on a grid other than the native grid and other than the preferred target grid', 'gr6z': 'regridded zonal mean data reported on a grid other than the native latitude grid and other than the preferred latitude target grid', 'gr7': 'regridded data reported on a grid other than the native grid and other than the preferred target grid', 'gr7a': 'regridded data reported in the region of Antarctica on a grid other than the native grid and other than the preferred target grid', 'gr7g': 'regridded data reported in the region of Greenland on a grid other than the native grid and other than the preferred target grid', 'gr7z': 'regridded zonal mean data rep ...

# %%
import json

# Creating a more detailed schema for the CMIP grid labels
schema = {
    "$schema": "http://json-schema.org/draft-07/schema#",
    "title": "CMIP Grid Labels",
    "description": "Schema for defining CMIP grid labels and their associated metadata",
    "type": "object",
    "properties": {
        "@id": {
            "type": "string",
            "description": "Unique identifier for the grid label, following the pattern mip-cmor-tables:grid/label/[label]",
            "pattern": "^mip-cmor-tables:grid/label/[a-zA-Z0-9]+$"
        },
        "@type": {
            "type": "string",
            "description": "Type of the object, should be mip:grid-label",
            "enum": ["mip:grid-label"]
        },
        "acronym": {
            "type": "string",
            "description": "Acronym representing the grid label"
        },
        "short name": {
            "type": "string",
            "description": "Short name or alias for the grid label"
        },
        "description": {
            "type": "string",
            "description": "Full description of the grid label"
        },
        "region": {
            "type": "string",
            "description": "Region associated with the grid label, can be global, antarctica, or greenland",
            "enum": ["global", "antarctica", "greenland"]
        }
    },
    "required": ["@id", "@type", "acronym", "short name", "description", "region"]
}

with open(f"label/schema.jsonld", "w") as f:
    f.write(json.dumps(schema, indent=4))


# # Minified schema for output
# minified_schema = json.dumps(schema, separators=(',', ':'))
# minified_schema

# %%
from pprint import pprint
import json
for i,d in label_data.items():
    print(i,label_data[i]["short_name"],label_data[i]["full_description"],label_data[i]["region"])
    
    
    jout = {
        "@id": f"mip-cmor-tables:grid/label/{i.lower().strip()}",
        "@type": "grid-label",
        "acronym": i,
        "short name": label_data[i]["short_name"],  
        "description": label_data[i]["full_description"],
        "region": label_data[i]["region"].lower()
        
    }
    
    with open(f"label/{i.lower().strip()}.json", "w") as f:
        f.write(json.dumps(jout, indent=4))
    
    pprint(jout)
# Out:
# gm Greenland global mean data Greenland
# {'@id': 'mip-cmor-tables:grid/label/gm',
#  '@type': 'grid-label',
#  'acronym': 'gm',
#  'description': 'global mean data',
#  'region': 'greenland',
#  'short name': 'Greenland'}
# gn Grid Native Greenland data reported on a model's native grid Greenland
# {'@id': 'mip-cmor-tables:grid/label/gn',
#  '@type': 'grid-label',
#  'acronym': 'gn',
#  'description': "data reported on a model's native grid",
#  'region': 'greenland',
#  'short name': 'Grid Native Greenland'}
# gna Grid Native Antarctica Greenland data reported on a native grid in the region of Antarctica Antarctica
# {'@id': 'mip-cmor-tables:grid/label/gna',
#  '@type': 'grid-label',
#  'acronym': 'gna',
#  'description': 'data reported on a native grid in the region of Antarctica',
#  'region': 'antarctica',
#  'short name': 'Grid Native Antarctica Greenland'}
# gng Grid Native Greenland data reported on a native grid in the region of Greenland Greenland
# {'@id': 'mip-cmor-tables:grid/label/gng',
#  '@type': 'grid-label',
#  'acronym': 'gng',
#  'description': 'data reported on a native grid in the region of Greenland',
#  'region': 'greenland',
#  'short name': 'Grid Native Greenland'}
# gnz Grid Native Greenland Zonal Mean zonal mean data reported on a model's native latitude grid Greenland
# {'@id': 'mip-cmor-tables:grid/label/gnz',
#  '@type': 'grid-label',
#  'acronym': 'gnz',
#  'description': "zonal mean data reported on a model's native latitude grid",
#  'region': 'greenland',
#  'short name': 'Grid Native Greenland Zonal Mean'}
# gr Regridded Greenland regridded data reported on the data provider's preferred target grid Greenland
# {'@id': 'mip-cmor-tables:grid/label/gr',
#  '@type': 'grid-label',
#  'acronym': 'gr',
#  'description': "regridded data reported on the data provider's preferred "
#                 'target grid',
#  'region': 'greenland',
#  'short name': 'Regridded Greenland'}
# gr1 Regridded Greenland Alternate 1 regridded data reported on a grid other than the native grid and other than the preferred target grid Greenland
# {'@id': 'mip-cmor-tables:grid/label/gr1',
#  '@type': 'grid-label',
#  'acronym': 'gr1',
#  'description': 'regridded data reported on a grid other than the native grid '
#                 'and other than the preferred target grid',
#  'region': 'greenland',
#  'short name': 'Regridded Greenland Alternate 1'}
# gr1a Regridded Antarctica Greenland Alternate a regridded data reported in the region of Antarctica on a grid other than the native grid and other than the preferred target grid Antarctica
# {'@id': 'mip-cmor-tables:grid/label/gr1a',
#  '@type': 'grid-label',
#  'acronym': 'gr1a',
#  'description': 'regridded data reported in the region of Antarctica on a grid '
#                 'other than the native grid and other than the preferred '
#                 'target grid',
#  'region': 'antarctica',
#  'short name': 'Regridded Antarctica Greenland Alternate a'}
# gr1g Regridded Greenland Alternate g regridded data reported in the region of Greenland on a grid other than the native grid and other than the preferred target grid Greenland
# {'@id': 'mip-cmor-tables:grid/label/gr1g',
#  '@type': 'grid-label',
#  'acronym': 'gr1g',
#  'description': 'regridded data reported in the region of Greenland on a grid '
#                 'other than the native grid and other than the preferred '
#                 'target grid',
#  'region': 'greenland',
#  'short name': 'Regridded Greenland Alternate g'}
# gr1z Regridded Greenland Zonal Mean Alternate z regridded zonal mean data reported on a grid other than the native latitude grid and other than the preferred latitude target grid Greenland
# {'@id': 'mip-cmor-tables:grid/label/gr1z',
#  '@type': 'grid-label',
#  'acronym': 'gr1z',
#  'description': 'regridded zonal mean data reported on a grid other than the '
#                 'native latitude grid and other than the preferred latitude '
#                 'target grid',
#  'region': 'greenland',
#  'short name': 'Regridded Greenland Zonal Mean Alternate z'}
# gr2 Regridded Greenland Alternate 2 regridded data reported on a grid other than the native grid and other than the preferred target grid Greenland
# {'@id': 'mip-cmor-tables:grid/label/gr2',
#  '@type': 'grid-label',
#  'acronym': 'gr2',
#  'description': 'regridded data reported on a grid other than the native grid '
#                 'and other than the preferred target grid',
#  'region': 'greenland',
#  'short name': 'Regridded Greenland Alternate 2'}
# gr2a Regridded Antarctica Greenland Alternate a regridded data reported in the region of Antarctica on a grid other than the native grid and other than the preferred target grid Antarctica
# {'@id': 'mip-cmor-tables:grid/label/gr2a',
#  '@type': 'grid-label',
#  'acronym': 'gr2a',
#  'description': 'regridded data reported in the region of Antarctica on a grid '
#                 'other than the native grid and other than the preferred '
#                 'target grid',
#  'region': 'antarctica',
#  'short name': 'Regridded Antarctica Greenland Alternate a'}
# gr2g Regridded Greenland Alternate g regridded data reported in the region of Greenland on a grid other than the native grid and other than the preferred target grid Greenland
# {'@id': 'mip-cmor-tables:grid/label/gr2g',
#  '@type': 'grid-label',
#  'acronym': 'gr2g',
#  'description': 'regridded data reported in the region of Greenland on a grid '
#                 'other than the native grid and other than the preferred '
#                 'target grid',
#  'region': 'greenland',
#  'short name': 'Regridded Greenland Alternate g'}
# gr2z Regridded Greenland Zonal Mean Alternate z regridded zonal mean data reported on a grid other than the native latitude grid and other than the preferred latitude target grid Greenland
# {'@id': 'mip-cmor-tables:grid/label/gr2z',
#  '@type': 'grid-label',
#  'acronym': 'gr2z',
#  'description': 'regridded zonal mean data reported on a grid other than the '
#                 'native latitude grid and other than the preferred latitude '
#                 'target grid',
#  'region': 'greenland',
#  'short name': 'Regridded Greenland Zonal Mean Alternate z'}
# gr3 Regridded Greenland Alternate 3 regridded data reported on a grid other than the native grid and other than the preferred target grid Greenland
# {'@id': 'mip-cmor-tables:grid/label/gr3',
#  '@type': 'grid-label',
#  'acronym': 'gr3',
#  'description': 'regridded data reported on a grid other than the native grid '
#                 'and other than the preferred target grid',
#  'region': 'greenland',
#  'short name': 'Regridded Greenland Alternate 3'}
# gr3a Regridded Antarctica Greenland Alternate a regridded data reported in the region of Antarctica on a grid other than the native grid and other than the preferred target grid Antarctica
# {'@id': 'mip-cmor-tables:grid/label/gr3a',
#  '@type': 'grid-label',
#  'acronym': 'gr3a',
#  'description': 'regridded data reported in the region of Antarctica on a grid '
#                 'other than the native grid and other than the preferred '
#                 'target grid',
#  'region': 'antarctica',
#  'short name': 'Regridded Antarctica Greenland Alternate a'}
# gr3g Regridded Greenland Alternate g regridded data reported in the region of Greenland on a grid other than the native grid and other than the preferred target grid Greenland
# {'@id': 'mip-cmor-tables:grid/label/gr3g',
#  '@type': 'grid-label',
#  'acronym': 'gr3g',
#  'description': 'regridded data reported in the region of Greenland on a grid '
#                 'other than the native grid and other than the preferred '
#                 'target grid',
#  'region': 'greenland',
#  'short name': 'Regridded Greenland Alternate g'}
# gr3z Regridded Greenland Zonal Mean Alternate z regridded zonal mean data reported on a grid other than the native latitude grid and other than the preferred latitude target grid Greenland
# {'@id': 'mip-cmor-tables:grid/label/gr3z',
#  '@type': 'grid-label',
#  'acronym': 'gr3z',
#  'description': 'regridded zonal mean data reported on a grid other than the '
#                 'native latitude grid and other than the preferred latitude '
#                 'target grid',
#  'region': 'greenland',
#  'short name': 'Regridded Greenland Zonal Mean Alternate z'}
# gr4 Regridded Greenland Alternate 4 regridded data reported on a grid other than the native grid and other than the preferred target grid Greenland
# {'@id': 'mip-cmor-tables:grid/label/gr4',
#  '@type': 'grid-label',
#  'acronym': 'gr4',
#  'description': 'regridded data reported on a grid other than the native grid '
#                 'and other than the preferred target grid',
#  'region': 'greenland',
#  'short name': 'Regridded Greenland Alternate 4'}
# gr4a Regridded Antarctica Greenland Alternate a regridded data reported in the region of Antarctica on a grid other than the native grid and other than the preferred target grid Antarctica
# {'@id': 'mip-cmor-tables:grid/label/gr4a',
#  '@type': 'grid-label',
#  'acronym': 'gr4a',
#  'description': 'regridded data reported in the region of Antarctica on a grid '
#                 'other than the native grid and other than the preferred '
#                 'target grid',
#  'region': 'antarctica',
#  'short name': 'Regridded Antarctica Greenland Alternate a'}
# gr4g Regridded Greenland Alternate g regridded data reported in the region of Greenland on a grid other than the native grid and other than the preferred target grid Greenland
# {'@id': 'mip-cmor-tables:grid/label/gr4g',
#  '@type': 'grid-label',
#  'acronym': 'gr4g',
#  'description': 'regridded data reported in the region of Greenland on a grid '
#                 'other than the native grid and other than the preferred '
#                 'target grid',
#  'region': 'greenland',
#  'short name': 'Regridded Greenland Alternate g'}
# gr4z Regridded Greenland Zonal Mean Alternate z regridded zonal mean data reported on a grid other than the native latitude grid and other than the preferred latitude target grid Greenland
# {'@id': 'mip-cmor-tables:grid/label/gr4z',
#  '@type': 'grid-label',
#  'acronym': 'gr4z',
#  'description': 'regridded zonal mean data reported on a grid other than the '
#                 'native latitude grid and other than the preferred latitude '
#                 'target grid',
#  'region': 'greenland',
#  'short name': 'Regridded Greenland Zonal Mean Alternate z'}
# gr5 Regridded Greenland Alternate 5 regridded data reported on a grid other than the native grid and other than the preferred target grid Greenland
# {'@id': 'mip-cmor-tables:grid/label/gr5',
#  '@type': 'grid-label',
#  'acronym': 'gr5',
#  'description': 'regridded data reported on a grid other than the native grid '
#                 'and other than the preferred target grid',
#  'region': 'greenland',
#  'short name': 'Regridded Greenland Alternate 5'}
# gr5a Regridded Antarctica Greenland Alternate a regridded data reported in the region of Antarctica on a grid other than the native grid and other than the preferred target grid Antarctica
# {'@id': 'mip-cmor-tables:grid/label/gr5a',
#  '@type': 'grid-label',
#  'acronym': 'gr5a',
#  'description': 'regridded data reported in the region of Antarctica on a grid '
#                 'other than the native grid and other than the preferred '
#                 'target grid',
#  'region': 'antarctica',
#  'short name': 'Regridded Antarctica Greenland Alternate a'}
# gr5g Regridded Greenland Alternate g regridded data reported in the region of Greenland on a grid other than the native grid and other than the preferred target grid Greenland
# {'@id': 'mip-cmor-tables:grid/label/gr5g',
#  '@type': 'grid-label',
#  'acronym': 'gr5g',
#  'description': 'regridded data reported in the region of Greenland on a grid '
#                 'other than the native grid and other than the preferred '
#                 'target grid',
#  'region': 'greenland',
#  'short name': 'Regridded Greenland Alternate g'}
# gr5z Regridded Greenland Zonal Mean Alternate z regridded zonal mean data reported on a grid other than the native latitude grid and other than the preferred latitude target grid Greenland
# {'@id': 'mip-cmor-tables:grid/label/gr5z',
#  '@type': 'grid-label',
#  'acronym': 'gr5z',
#  'description': 'regridded zonal mean data reported on a grid other than the '
#                 'native latitude grid and other than the preferred latitude '
#                 'target grid',
#  'region': 'greenland',
#  'short name': 'Regridded Greenland Zonal Mean Alternate z'}
# gr6 Regridded Greenland Alternate 6 regridded data reported on a grid other than the native grid and other than the preferred target grid Greenland
# {'@id': 'mip-cmor-tables:grid/label/gr6',
#  '@type': 'grid-label',
#  'acronym': 'gr6',
#  'description': 'regridded data reported on a grid other than the native grid '
#                 'and other than the preferred target grid',
#  'region': 'greenland',
#  'short name': 'Regridded Greenland Alternate 6'}
# gr6a Regridded Antarctica Greenland Alternate a regridded data reported in the region of Antarctica on a grid other than the native grid and other than the preferred target grid Antarctica
# {'@id': 'mip-cmor-tables:grid/label/gr6a',
#  '@type': 'grid-label',
#  'acronym': 'gr6a',
#  'description': 'regridded data reported in the region of Antarctica on a grid '
#                 'other than the native grid and other than the preferred '
#                 'target grid',
#  'region': 'antarctica',
#  'short name': 'Regridded Antarctica Greenland Alternate a'}
# gr6g Regridded Greenland Alternate g regridded data reported in the region of Greenland on a grid other than the native grid and other than the preferred target grid Greenland
# {'@id': 'mip-cmor-tables:grid/label/gr6g',
#  '@type': 'grid-label',
#  'acronym': 'gr6g',
#  'description': 'regridded data reported in the region of Greenland on a grid '
#                 'other than the native grid and other than the preferred '
#                 'target grid',
#  'region': 'greenland',
#  'short name': 'Regridded Greenland Alternate g'}
# gr6z Regridded Greenland Zonal Mean Alternate z regridded zonal mean data reported on a grid other than the native latitude grid and other than the preferred latitude target grid Greenland
# {'@id': 'mip-cmor-tables:grid/label/gr6z',
#  '@type': 'grid-label',
#  'acronym': 'gr6z',
#  'description': 'regridded zonal mean data reported on a grid other than the '
#                 'native latitude grid and other than the preferred latitude '
#                 'target grid',
#  'region': 'greenland',
#  'short name': 'Regridded Greenland Zonal Mean Alternate z'}
# gr7 Regridded Greenland Alternate 7 regridded data reported on a grid other than the native grid and other than the preferred target grid Greenland
# {'@id': 'mip-cmor-tables:grid/label/gr7',
#  '@type': 'grid-label',
#  'acronym': 'gr7',
#  'description': 'regridded data reported on a grid other than the native grid '
#                 'and other than the preferred target grid',
#  'region': 'greenland',
#  'short name': 'Regridded Greenland Alternate 7'}
# gr7a Regridded Antarctica Greenland Alternate a regridded data reported in the region of Antarctica on a grid other than the native grid and other than the preferred target grid Antarctica
# {'@id': 'mip-cmor-tables:grid/label/gr7a',
#  '@type': 'grid-label',
#  'acronym': 'gr7a',
#  'description': 'regridded data reported in the region of Antarctica on a grid '
#                 'other than the native grid and other than the preferred '
#                 'target grid',
#  'region': 'antarctica',
#  'short name': 'Regridded Antarctica Greenland Alternate a'}
# gr7g Regridded Greenland Alternate g regridded data reported in the region of Greenland on a grid other than the native grid and other than the preferred target grid Greenland
# {'@id': 'mip-cmor-tables:grid/label/gr7g',
#  '@type': 'grid-label',
#  'acronym': 'gr7g',
#  'description': 'regridded data reported in the region of Greenland on a grid '
#                 'other than the native grid and other than the preferred '
#                 'target grid',
#  'region': 'greenland',
#  'short name': 'Regridded Greenland Alternate g'}
# gr7z Regridded Greenland Zonal Mean Alternate z regridded zonal mean data reported on a grid other than the native latitude grid and other than the preferred latitude target grid Greenland
# {'@id': 'mip-cmor-tables:grid/label/gr7z',
#  '@type': 'grid-label',
#  'acronym': 'gr7z',
#  'description': 'regridded zonal mean data reported on a grid other than the '
#                 'native latitude grid and other than the preferred latitude '
#                 'target grid',
#  'region': 'greenland',
#  'short name': 'Regridded Greenland Zonal Mean Alternate z'}
# gr8 Regridded Greenland Alternate 8 regridded data reported on a grid other than the native grid and other than the preferred target grid Greenland
# {'@id': 'mip-cmor-tables:grid/label/gr8',
#  '@type': 'grid-label',
#  'acronym': 'gr8',
#  'description': 'regridded data reported on a grid other than the native grid '
#                 'and other than the preferred target grid',
#  'region': 'greenland',
#  'short name': 'Regridded Greenland Alternate 8'}
# gr8a Regridded Antarctica Greenland Alternate a regridded data reported in the region of Antarctica on a grid other than the native grid and other than the preferred target grid Antarctica
# {'@id': 'mip-cmor-tables:grid/label/gr8a',
#  '@type': 'grid-label',
#  'acronym': 'gr8a',
#  'description': 'regridded data reported in the region of Antarctica on a grid '
#                 'other than the native grid and other than the preferred '
#                 'target grid',
#  'region': 'antarctica',
#  'short name': 'Regridded Antarctica Greenland Alternate a'}
# gr8g Regridded Greenland Alternate g regridded data reported in the region of Greenland on a grid other than the native grid and other than the preferred target grid Greenland
# {'@id': 'mip-cmor-tables:grid/label/gr8g',
#  '@type': 'grid-label',
#  'acronym': 'gr8g',
#  'description': 'regridded data reported in the region of Greenland on a grid '
#                 'other than the native grid and other than the preferred '
#                 'target grid',
#  'region': 'greenland',
#  'short name': 'Regridded Greenland Alternate g'}
# gr8z Regridded Greenland Zonal Mean Alternate z regridded zonal mean data reported on a grid other than the native latitude grid and other than the preferred latitude target grid Greenland
# {'@id': 'mip-cmor-tables:grid/label/gr8z',
#  '@type': 'grid-label',
#  'acronym': 'gr8z',
#  'description': 'regridded zonal mean data reported on a grid other than the '
#                 'native latitude grid and other than the preferred latitude '
#                 'target grid',
#  'region': 'greenland',
#  'short name': 'Regridded Greenland Zonal Mean Alternate z'}
# gr9 Regridded Greenland Alternate 9 regridded data reported on a grid other than the native grid and other than the preferred target grid Greenland
# {'@id': 'mip-cmor-tables:grid/label/gr9',
#  '@type': 'grid-label',
#  'acronym': 'gr9',
#  'description': 'regridded data reported on a grid other than the native grid '
#                 'and other than the preferred target grid',
#  'region': 'greenland',
#  'short name': 'Regridded Greenland Alternate 9'}
# gr9a Regridded Antarctica Greenland Alternate a regridded data reported in the region of Antarctica on a grid other than the native grid and other than the preferred target grid Antarctica
# {'@id': 'mip-cmor-tables:grid/label/gr9a',
#  '@type': 'grid-label',
#  'acronym': 'gr9a',
#  'description': 'regridded data reported in the region of Antarctica on a grid '
#                 'other than the native grid and other than the preferred '
#                 'target grid',
#  'region': 'antarctica',
#  'short name': 'Regridded Antarctica Greenland Alternate a'}
# gr9g Regridded Greenland Alternate g regridded data reported in the region of Greenland on a grid other than the native grid and other than the preferred target grid Greenland
# {'@id': 'mip-cmor-tables:grid/label/gr9g',
#  '@type': 'grid-label',
#  'acronym': 'gr9g',
#  'description': 'regridded data reported in the region of Greenland on a grid '
#                 'other than the native grid and other than the preferred '
#                 'target grid',
#  'region': 'greenland',
#  'short name': 'Regridded Greenland Alternate g'}
# gr9z Regridded Greenland Zonal Mean Alternate z regridded zonal mean data reported on a grid other than the native latitude grid and other than the preferred latitude target grid Greenland
# {'@id': 'mip-cmor-tables:grid/label/gr9z',
#  '@type': 'grid-label',
#  'acronym': 'gr9z',
#  'description': 'regridded zonal mean data reported on a grid other than the '
#                 'native latitude grid and other than the preferred latitude '
#                 'target grid',
#  'region': 'greenland',
#  'short name': 'Regridded Greenland Zonal Mean Alternate z'}
# gra Regridded Antarctica Greenland regridded data in the region of Antarctica reported on the data provider's preferred target grid Antarctica
# {'@id': 'mip-cmor-tables:grid/label/gra',
#  '@type': 'grid-label',
#  'acronym': 'gra',
#  'description': 'regridded data in the region of Antarctica reported on the '
#                 "data provider's preferred target grid",
#  'region': 'antarctica',
#  'short name': 'Regridded Antarctica Greenland'}
# grg Regridded Greenland regridded data in the region of Greenland reported on the data provider's preferred target grid Greenland
# {'@id': 'mip-cmor-tables:grid/label/grg',
#  '@type': 'grid-label',
#  'acronym': 'grg',
#  'description': 'regridded data in the region of Greenland reported on the '
#                 "data provider's preferred target grid",
#  'region': 'greenland',
#  'short name': 'Regridded Greenland'}
# grz Regridded Greenland Zonal Mean regridded zonal mean data reported on the data provider's preferred latitude target grid Greenland
# {'@id': 'mip-cmor-tables:grid/label/grz',
#  '@type': 'grid-label',
#  'acronym': 'grz',
#  'description': "regridded zonal mean data reported on the data provider's "
#                 'preferred latitude target grid',
#  'region': 'greenland',
#  'short name': 'Regridded Greenland Zonal Mean'}

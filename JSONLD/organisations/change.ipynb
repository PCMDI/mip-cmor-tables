# %%
import json, os, glob
from jsonschema import validate,exceptions
import pprint

def validate_json(data, schema, name = 'none', success=True):
    try:
        validate(instance=data, schema=schema)
        if success:
            print(f"Validation succeeded: {name}")
    except exceptions.ValidationError as err:
        print("Validation error:",name, err.message,)
# Out:
# {'@id': 'mip-cmor-tables/institutions/bcc',
#  '@type': 'cmip:institution',
#  'institution:acronyms': [],
#  'institution:aliases': [],
#  'institution:cmip_acronym': 'BCC',
#  'institution:established': 2008,
#  'institution:labels': [],
#  'institution:location': {'@id': 'mip-cmor-tables/institutions/location/01spyyb53',
#                           '@nest': {'location:city': 'Beijing',
#                                     'location:country': ['China', 'CN'],
#                                     'location:lat': 39.950128,
#                                     'location:lon': 116.383679},
#                           '@type': 'institution:location'},
#  'institution:name': 'Beijing Biocytogen (China)',
#  'institution:ror': '01spyyb53',
#  'institution:type': 'Company',
#  'institution:url': ['http://www.bbctg.com.cn/']}

# %%
      
inst = glob.glob('institutions/*.json')

schema = {
  "$schema": "http://json-schema.org/draft-07/schema#",
  "title": "Institution Data Schema",
  "type": "object",
  "properties": {
    "@id": {
      "type": "string",
      "pattern": "^mip-cmor-tables:organisations/institutions/.*$"
    },
    "@type": {
      "type": "string",
      "enum": ["cmip:institution"]
    },
    "institution:acronyms": {
      "type": "array",
      "items": {
        "type": "string"
      }
    },
    "institution:aliases": {
      "type": "array",
      "items": {
        "type": "string"
      }
    },
    "institution:cmip_acronym": {
      "type": "string"
    },
    "institution:established": {
      "type": "integer",
      "minimum": 0
    },
    "institution:labels": {
      "type": "array",
      "items": {
        "type": "string"
      }
    },
    "institution:location": {
      "type": "object",
      "properties": {
        "@id": {
          "type": "string",
          "pattern": "^mip-cmor-tables:organisations/institutions/location/.*$"
        },
        "@nest": {
          "type": "object",
          "properties": {
            "location:city": {
              "type": "string"
            },
            "location:country": {
              "type": "array",
              "items": {
                "type": "string"
              }
            },
            "location:lat": {
              "type": "number"
            },
            "location:lon": {
              "type": "number"
            }
          },
          "required": ["location:city", "location:country", "location:lat", "location:lon"]
        },
        "@type": {
          "type": "string",
          "enum": ["institution:location"]
        }
      },
      "required": ["@id", "@nest", "@type"]
    },
    "institution:name": {
      "type": "string"
    },
    "institution:ror": {
      "type": "string"
    },
    "institution:type": {
      "type": "string"
    },
    "institution:url": {
      "type": "array",
      "items": {
        "type": "string",
        "format": "uri"
      }
    }
  },
  "required": [
    "@id",
    "@type",
    "institution:acronyms",
    "institution:aliases",
    "institution:cmip_acronym",
    "institution:established",
    "institution:labels",
    "institution:location",
    "institution:name",
    "institution:ror",
    "institution:type",
    "institution:url"
  ]
}

json.dump(schema,open('institutions/schema.json','w'),indent=4)


for iloc in inst:
    text = open(iloc,'r').read()
    textnew = text.replace('mip-cmor-tables/institutions','mip-cmor-tables:organisations/institutions')
    print(iloc)
    js = json.loads(textnew)
    # pprint.pprint(js)
    
    validate_json(js,schema,iloc)
    
    # print(f'./inst/{iloc.lower()}')
    # with open(f'./inst/{iloc.lower()}','w') as f:
    #   jst = json.dumps(js,indent=4)
    #   f.write(jst)
    #   # os.system(f'rm {iloc}')
# Out:
# institutions/BCC.json
# Validation succeeded: institutions/BCC.json
# ./inst/institutions/bcc.json
# institutions/UA.json
# Validation succeeded: institutions/UA.json
# ./inst/institutions/ua.json
# institutions/NTU.json
# Validation succeeded: institutions/NTU.json
# ./inst/institutions/ntu.json
# institutions/NASA-GSFC.json
# Validation succeeded: institutions/NASA-GSFC.json
# ./inst/institutions/nasa-gsfc.json
# institutions/CCCma.json
# Validation succeeded: institutions/CCCma.json
# ./inst/institutions/cccma.json
# institutions/CNES.json
# Validation succeeded: institutions/CNES.json
# ./inst/institutions/cnes.json
# institutions/MPI-M.json
# Validation succeeded: institutions/MPI-M.json
# ./inst/institutions/mpi-m.json
# institutions/NUIST.json
# Validation succeeded: institutions/NUIST.json
# ./inst/institutions/nuist.json
# institutions/AER.json
# Validation succeeded: institutions/AER.json
# ./inst/institutions/aer.json
# institutions/MOHC.json
# Validation succeeded: institutions/MOHC.json
# ./inst/institutions/mohc.json
# institutions/CAS.json
# Validation succeeded: institutions/CAS.json
# ./inst/institutions/cas.json
# institutions/CMCC.json
# Validation succeeded: institutions/CMCC.json
# ./inst/institutions/cmcc.json
# institutions/UofMD.json
# Validation succeeded: institutions/UofMD.json
# ./inst/institutions/uofmd.json
# institutions/DKRZ.json
# Validation succeeded: institutions/DKRZ.json
# ./inst/institutions/dkrz.json
# institutions/NOAA-NCEI.json
# Validation succeeded: institutions/NOAA-NCEI.json
# ./inst/institutions/noaa-ncei.json
# institutions/MRI.json
# Validation succeeded: institutions/MRI.json
# ./inst/institutions/mri.json
# institutions/PNNL-WACCEM.json
# Validation succeeded: institutions/PNNL-WACCEM.json
# ./inst/institutions/pnnl-waccem.json
# institutions/LLNL.json
# Validation succeeded: institutions/LLNL.json
# ./inst/institutions/llnl.json
# institutions/NERC.json
# Validation succeeded: institutions/NERC.json
# ./inst/institutions/nerc.json
# institutions/IACETH.json
# Validation succeeded: institutions/IACETH.json
# ./inst/institutions/iaceth.json
# institutions/RSS.json
# Validation succeeded: institutions/RSS.json
# ./inst/institutions/rss.json
# institutions/NCAR.json
# Validation succeeded: institutions/NCAR.json
# ./inst/institutions/ncar.json
# institutions/CSIRO.json
# Validation succeeded: institutions/CSIRO.json
# ./inst/institutions/csiro.json
# institutions/ESSO.json
# Validation succeeded: institutions/ESSO.json
# ./inst/institutions/esso.json
# institutions/THU.json
# Validation succeeded: institutions/THU.json
# ./inst/institutions/thu.json
# institutions/UHH.json
# Validation succeeded: institutions/UHH.json
# ./inst/institutions/uhh.json
# institutions/AWI.json
# Validation succeeded: institutions/AWI.json
# ./inst/institutions/awi.json
# institutions/CAMS.json
# Validation succeeded: institutions/CAMS.json
# ./inst/institutions/cams.json
# institutions/ECMWF.json
# Validation succeeded: institutions/ECMWF.json
# ./inst/institutions/ecmwf.json
# institutions/ImperialCollege.json
# Validation succeeded: institutions/ImperialCollege.json
# ./inst/institutions/imperialcollege.json
# institutions/PCMDI.json
# Validation succeeded: institutions/PCMDI.json
# ./inst/institutions/pcmdi.json
# institutions/VUA.json
# Validation succeeded: institutions/VUA.json
# ./inst/institutions/vua.json
# institutions/NCAS.json
# Validation succeeded: institutions/NCAS.json
# ./inst/institutions/ncas.json
# institutions/NASA-GISS.json
# Validation succeeded: institutions/NASA-GISS.json
# ./inst/institutions/nasa-giss.json
# institutions/DWD.json
# Validation succeeded: institutions/DWD.json
# ./inst/institutions/dwd.json
# institutions/UoM.json
# Validation succeeded: institutions/UoM.json
# ./inst/institutions/uom.json
# institutions/KIOST.json
# Validation succeeded: institutions/KIOST.json
# ./inst/institutions/kiost.json
# institutions/UColorado.json
# Validation succeeded: institutions/UColorado.json
# ./inst/institutions/ucolorado.json
# institutions/CCCR-IITM.json
# Validation succeeded: institutions/CCCR-IITM.json
# ./inst/institutions/cccr-iitm.json
# institutions/NASA-LaRC.json
# Validation succeeded: institutions/NASA-LaRC.json
# ./inst/institutions/nasa-larc.json
# institutions/SNU.json
# Validation succeeded: institutions/SNU.json
# ./inst/institutions/snu.json
# institutions/INM.json
# Validation succeeded: institutions/INM.json
# ./inst/institutions/inm.json
# institutions/PNNL-JGCRI.json
# Validation succeeded: institutions/PNNL-JGCRI.json
# ./inst/institutions/pnnl-jgcri.json
# institutions/schema.json
# Validation error: institutions/schema.json '@id' is a required property
# ./inst/institutions/schema.json
# institutions/SOLARIS-HEPPA.json
# Validation succeeded: institutions/SOLARIS-HEPPA.json
# ./inst/institutions/solaris-heppa.json
# institutions/UReading.json
# Validation succeeded: institutions/UReading.json
# ./inst/institutions/ureading.json
# institutions/NASA-JPL.json
# Validation succeeded: institutions/NASA-JPL.json
# ./inst/institutions/nasa-jpl.json
# institutions/AS-RCEC.json
# Validation error: institutions/AS-RCEC.json None is not of type 'integer'
# ./inst/institutions/as-rcec.json
# institutions/NIWA.json
# Validation succeeded: institutions/NIWA.json
# ./inst/institutions/niwa.json
# institutions/UCI.json
# Validation succeeded: institutions/UCI.json
# ./inst/institutions/uci.json
# institutions/OSU.json
# Validation succeeded: institutions/OSU.json
# ./inst/institutions/osu.json
# institutions/MPI-B.json
# Validation succeeded: institutions/MPI-B.json
# ./inst/institutions/mpi-b.json
# institutions/JAXA.json
# Validation succeeded: institutions/JAXA.json
# ./inst/institutions/jaxa.json
# institutions/UW.json
# Validation succeeded: institutions/UW.json
# ./inst/institutions/uw.json
# institutions/UCSB.json
# Validation succeeded: institutions/UCSB.json
# ./inst/institutions/ucsb.json
# institutions/CEDA.json
# Validation succeeded: institutions/CEDA.json
# ./inst/institutions/ceda.json
# institutions/IPSL.json
# Validation succeeded: institutions/IPSL.json
# ./inst/institutions/ipsl.json

# %%
      
inst = glob.glob('consortia/*.json')

schema = {
  "$schema": "http://json-schema.org/draft-07/schema#",
  "title": "Consortium Data Schema",
  "type": "object",
  "properties": {
    "@id": {
      "type": "string",
      "pattern": "^mip-cmor-tables:organisations/consortia/.*$"
    },
    "@type": {
      "type": "string",
      "enum": ["cmip:consortium"]
    },
    "consortium:cmip_acronym": {
      "type": "string"
    },
    "consortium:description": {
      "type": "string"
    },
    "consortium:url": {
      "type": "string"
    },
    "consortium:changes": {
      "type": "string"
    },
    "consortium:members": {
      "type": "object",
      "properties": {
        "@set": {
          "type": "array",
          "items": {
            "type": "object",
            "properties": {
              "@id": {
                "type": "string"
              }
            },
            "required": ["@id"]
          }
        }
      },
      "required": ["@set"]
    }
  },
  "required": [
    "@id",
    "@type",
    "consortium:cmip_acronym",
    "consortium:description",
    "consortium:url",
    "consortium:changes",
    "consortium:members"
  ]
}


json.dump(schema,open('consortia/schema.json','w'),indent=4)


for iloc in inst:
    text = open(iloc,'r').read()
    textnew = text.replace('mip-cmor-tables/consortia','mip-cmor-tables:organisations/consortia')
    print(iloc)
    js = json.loads(textnew)
    # pprint.pprint(js)
    
    validate_json(js,schema,iloc)
    
    with open(f'./{iloc.lower()}','w') as f:
      jst = json.dumps(js,indent=4)
      f.write(jst)
      # os.system(f'rm {iloc}')
# Out:
# consortia/ncc.json
# Validation succeeded: consortia/ncc.json
# consortia/ec-earth-consortium.json
# Validation succeeded: consortia/ec-earth-consortium.json
# consortia/espri-ipsl.json
# Validation succeeded: consortia/espri-ipsl.json
# consortia/nims-kma.json
# Validation succeeded: consortia/nims-kma.json
# consortia/messy-consortium.json
# Validation succeeded: consortia/messy-consortium.json
# consortia/incois-nio-ipsl.json
# Validation succeeded: consortia/incois-nio-ipsl.json
# consortia/noaa-gfdl.json
# Validation succeeded: consortia/noaa-gfdl.json
# consortia/fio-qlnm.json
# Validation succeeded: consortia/fio-qlnm.json
# consortia/e3sm-project.json
# Validation succeeded: consortia/e3sm-project.json
# consortia/dlr-bira.json
# Validation succeeded: consortia/dlr-bira.json
# consortia/pcmdi.json
# Validation succeeded: consortia/pcmdi.json
# consortia/csiro-arccss.json
# Validation succeeded: consortia/csiro-arccss.json
# consortia/iamc.json
# Validation succeeded: consortia/iamc.json
# consortia/miroc.json
# Validation succeeded: consortia/miroc.json
# consortia/hammoz-consortium.json
# Validation succeeded: consortia/hammoz-consortium.json
# consortia/rte-rrtmgp-consortium.json
# Validation succeeded: consortia/rte-rrtmgp-consortium.json
# consortia/context.json
# Validation error: consortia/context.json '@id' is a required property
# consortia/ucsd-sio.json
# Validation succeeded: consortia/ucsd-sio.json
# consortia/schema.json
# Validation error: consortia/schema.json '@id' is a required property
# consortia/csiro-cosima.json
# Validation succeeded: consortia/csiro-cosima.json
# consortia/rubisco.json
# Validation succeeded: consortia/rubisco.json
# consortia/cnrm-cerfacs.json
# Validation succeeded: consortia/cnrm-cerfacs.json

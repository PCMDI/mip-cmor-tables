# %%
import json, os, glob
from jsonschema import validate,exceptions
import pprint

from pyld import jsonld

def validate_json(data, schema, name = 'none', success=True):
    try:
        validate(instance=data, schema=schema)
        if success:
            print(f"Validation succeeded: {name}")
    except exceptions.ValidationError as err:
        print("Validation error:",name, err.message,)

# %%
      
inst = glob.glob('institutions/*.json')

schema = {
  "$schema": "http://json-schema.org/draft-07/schema#",
  "title": "Institution Data Schema",
  "type": "object",
  "properties": {
    "@id": {
      "type": "string",
      "pattern": "^mip-cmor-tables:organisations/institutions/.*$"
    },
    "@type": {
      "type": "string",
      "enum": ["cmip:institution"]
    },
    "acronyms": {
      "type": "array",
      "items": {
        "type": "string"
      }
    },
    "aliases": {
      "type": "array",
      "items": {
        "type": "string"
      }
    },
    "cmip_acronym": {
      "type": "string"
    },
    "established": {
      "type": "integer",
      "minimum": 0
    },
    "labels": {
      "type": "array",
      "items": {
        "type": "string"
      }
    },
    "location": {
      "type": "object",
      "properties": {
        "@id": {
          "type": "string",
          "pattern": "^mip-cmor-tables:organisations/institutions/location/.*$"
        },
        "@nest": {
          "type": "object",
          "properties": {
            "city": {
              "type": "string"
            },
            "country": {
              "type": "array",
              "items": {
                "type": "string"
              }
            },
            "lat": {
              "type": "number"
            },
            "lon": {
              "type": "number"
            }
          },
          "required": ["city", "country", "lat", "lon"]
        },
        "@type": {
          "type": "string",
          "enum": ["location"]
        }
      },
      "required": ["@id", "@nest", "@type"]
    },
    "name": {
      "type": "string"
    },
    "ror": {
      "type": "string"
    },
    "type": {
      "type": "string"
    },
    "url": {
      "type": "array",
      "items": {
        "type": "string",
        "format": "uri"
      }
    }
  },
  "required": [
    "@id",
    "@type",
    "acronyms",
    "aliases",
    "cmip_acronym",
    "established",
    "labels",
    "location",
    "name",
    "ror",
    "type",
    "url"
  ]
}

json.dump(schema,open('institutions/schema.json','w'),indent=4)


for iloc in inst:
    text = open(iloc,'r').read()
    textnew = text.replace('mip-cmor-tables/institutions','mip-cmor-tables:organisations/institutions').replace('institution:','').replace('location:','')
    print(iloc)
    js = json.loads(textnew)
    # pprint.pprint(js)
    
    validate_json(js,schema,iloc)
    
    # print(f'./inst/{iloc.lower()}')
    with open(f'{iloc.lower()}','w') as f:
      jst = json.dumps(js,indent=4)
      f.write(jst)
    #   # os.system(f'rm {iloc}')
# Out:
# institutions/bcc.json
# Validation succeeded: institutions/bcc.json
# institutions/ua.json
# Validation succeeded: institutions/ua.json
# institutions/ntu.json
# Validation succeeded: institutions/ntu.json
# institutions/uootago.json
# Validation succeeded: institutions/uootago.json
# institutions/nasa-gsfc.json
# Validation succeeded: institutions/nasa-gsfc.json
# institutions/cccma.json
# Validation succeeded: institutions/cccma.json
# institutions/cnes.json
# Validation succeeded: institutions/cnes.json
# institutions/mpi-m.json
# Validation succeeded: institutions/mpi-m.json
# institutions/pmod.json
# Validation succeeded: institutions/pmod.json
# institutions/version.json
# Validation error: institutions/version.json [{'@id': '../../https://github.com/PCMDI/mip-cmor-tables/blob/main/JSONLD/organisations/institutions/uootago.json', '@type': 'version', 'version:file': '../../JSONLD/organisations/institutions/uootago.json', 'version:release': {'mip-cmor-tables': 'v6.5.0.2', 'cmip6plus': 'v6.5.1.4'}, 'version:previous_updates': 1, 'version:date': '2024-06-11T19:57:22+01:00', 'version:commit': {'hash': '0575cc0bfec0d27f4e98763e3df4c42aab1c6c00', 'message': 'New entry UoOtago to the Institutions LD file', 'author': {'name': 'berndfunke', 'email': 'berndfunke@users.noreply.github.com'}}, 'version:data': {'@id': '../../mip-cmor-tables:organisations/institutions/uootago'}}, {'@id': '../../https://github.com/PCMDI/mip-cmor-tables/blob/main/JSONLD/organisations/institutions/pmod.json', '@type': 'version', 'version:file': '../../JSONLD/organisations/institutions/pmod.json', 'version:release': {'mip-cmor-tables': 'v6.5.0.2', 'cmip6plus': 'v6.5.1.4'}, 'version:previous_updates': 1, 'version:date': '2024-06-11T19:57:22+01:00', 'version:commit': {'hash': '99a65565a7f6c20168f16ebfb790cd60b73bcbcf', 'message': 'New entry PMOD to the Institutions LD file', 'author': {'name': 'berndfunke', 'email': 'berndfunke@users.noreply.github.com'}}, 'version:data': {'@id': '../../mip-cmor-tables:organisations/institutions/pmod'}}, {'@id': '../../https://github.com/PCMDI/mip-cmor-tables/blob/main/JSONLD/organisations/institutions/nuist.json', '@type': 'version', 'version:file': '../../JSONLD/organisations/institutions/nuist.json', 'version:release': {'mip-cmor-tables': 'v6.5.0.2', 'cmip6plus': 'v6.5.1.4'}, 'version:previous_updates': 1, 'version:date': '2024-06-11T18:58:05+01:00', 'version:commit': {'hash': '5e9f49b8d90ab18b141737bf72b55534296a61af', 'message': 'adding JSON-ld files', 'author': {'name': 'Daniel', 'email': 'daniel.ellis@ext.esa.int'}}, 'version:data': {'@id': '../../mip-cmor-tables:organisations/institutions/nuist'}}, {'@id': '../../https://github.com/PCMDI/mip-cmor-tables/blob/main/JSONLD/organisations/institutions/cas.json', '@type': 'version', 'version:file': '../../JSONLD/organisations/institutions/cas.json', 'version:release': {'mip-cmor-tables': 'v6.5.0.2', 'cmip6plus': 'v6.5.1.4'}, 'version:previous_updates': 1, 'version:date': '2024-06-11T18:58:05+01:00', 'version:commit': {'hash': '5e9f49b8d90ab18b141737bf72b55534296a61af', 'message': 'adding JSON-ld files', 'author': {'name': 'Daniel', 'email': 'daniel.ellis@ext.esa.int'}}, 'version:data': {'@id': '../../mip-cmor-tables:organisations/institutions/cas'}}, {'@id': '../../https://github.com/PCMDI/mip-cmor-tables/blob/main/JSONLD/organisations/institutions/mohc.json', '@type': 'version', 'version:file': '../../JSONLD/organisations/institutions/mohc.json', 'version:release': {'mip-cmor-tables': 'v6.5.0.2', 'cmip6plus': 'v6.5.1.4'}, 'version:previous_updates': 2, 'version:date': '2024-06-11T19:57:22+01:00', 'version:commit': {'hash': '3e7ae29d6a88199d32aa189d27e8fc77bcfec286', 'message': 'framing update', 'author': {'name': 'Daniel Ellis', 'email': 'daniel.ellis@ext.esa.int'}}, 'version:data': {'@id': '../../mip-cmor-tables:organisations/institutions/mohc'}}, {'@id': '../../https://github.com/PCMDI/mip-cmor-tables/blob/main/JSONLD/organisations/institutions/cnes.json', '@type': 'version', 'version:file': '../../JSONLD/organisations/institutions/cnes.json', 'version:release': {'mip-cmor-tables': 'v6.5.0.2', 'cmip6plus': 'v6.5.1.4'}, 'version:previous_updates': 1, 'version:date': '2024-06-11T18:58:05+01:00', 'version:commit': {'hash': '5e9f49b8d90ab18b141737bf72b55534296a61af', 'message': 'adding JSON-ld files', 'author': {'name': 'Daniel', 'email': 'daniel.ellis@ext.esa.int'}}, 'version:data': {'@id': '../../mip-cmor-tables:organisations/institutions/cnes'}}, {'@id': '../../https://github.com/PCMDI/mip-cmor-tables/blob/main/JSONLD/organisations/institutions/bcc.json', '@type': 'version', 'version:file': '../../JSONLD/organisations/institutions/bcc.json', 'ver ...
# institutions/nuist.json
# Validation succeeded: institutions/nuist.json
# institutions/aer.json
# Validation succeeded: institutions/aer.json
# institutions/mohc.json
# Validation succeeded: institutions/mohc.json
# institutions/cas.json
# Validation succeeded: institutions/cas.json
# institutions/cmcc.json
# Validation succeeded: institutions/cmcc.json
# institutions/uofmd.json
# Validation succeeded: institutions/uofmd.json
# institutions/dkrz.json
# Validation succeeded: institutions/dkrz.json
# institutions/noaa-ncei.json
# Validation succeeded: institutions/noaa-ncei.json
# institutions/mri.json
# Validation succeeded: institutions/mri.json
# institutions/pnnl-waccem.json
# Validation succeeded: institutions/pnnl-waccem.json
# institutions/llnl.json
# Validation succeeded: institutions/llnl.json
# institutions/nerc.json
# Validation succeeded: institutions/nerc.json
# institutions/iaceth.json
# Validation succeeded: institutions/iaceth.json
# institutions/rss.json
# Validation succeeded: institutions/rss.json
# institutions/ncar.json
# Validation succeeded: institutions/ncar.json
# institutions/csiro.json
# Validation succeeded: institutions/csiro.json
# institutions/ifm-geomar.json
# Validation succeeded: institutions/ifm-geomar.json
# institutions/esso.json
# Validation succeeded: institutions/esso.json
# institutions/thu.json
# Validation succeeded: institutions/thu.json
# institutions/uhh.json
# Validation succeeded: institutions/uhh.json
# institutions/awi.json
# Validation succeeded: institutions/awi.json
# institutions/fuberlin.json
# Validation succeeded: institutions/fuberlin.json
# institutions/cams.json
# Validation succeeded: institutions/cams.json
# institutions/ecmwf.json
# Validation succeeded: institutions/ecmwf.json
# institutions/imperialcollege.json
# Validation succeeded: institutions/imperialcollege.json
# institutions/pcmdi.json
# Validation succeeded: institutions/pcmdi.json
# institutions/vua.json
# Validation succeeded: institutions/vua.json
# institutions/ncas.json
# Validation succeeded: institutions/ncas.json
# institutions/uooulu.json
# Validation succeeded: institutions/uooulu.json
# institutions/auot.json
# Validation succeeded: institutions/auot.json
# institutions/nasa-giss.json
# Validation succeeded: institutions/nasa-giss.json
# institutions/dwd.json
# Validation succeeded: institutions/dwd.json
# institutions/uom.json
# Validation succeeded: institutions/uom.json
# institutions/kiost.json
# Validation succeeded: institutions/kiost.json
# institutions/ucolorado.json
# Validation succeeded: institutions/ucolorado.json
# institutions/cccr-iitm.json
# Validation succeeded: institutions/cccr-iitm.json
# institutions/uomontreal.json
# Validation succeeded: institutions/uomontreal.json
# institutions/nasa-larc.json
# Validation succeeded: institutions/nasa-larc.json
# institutions/snu.json
# Validation succeeded: institutions/snu.json
# institutions/eawag.json
# Validation succeeded: institutions/eawag.json
# institutions/inm.json
# Validation succeeded: institutions/inm.json
# institutions/graph.json
# Validation error: institutions/graph.json 'acronyms' is a required property
# institutions/bas.json
# Validation succeeded: institutions/bas.json
# institutions/pnnl-jgcri.json
# Validation succeeded: institutions/pnnl-jgcri.json
# institutions/frame.json
# Validation error: institutions/frame.json '@id' is a required property
# institutions/schema.json
# Validation error: institutions/schema.json '@id' is a required property
# institutions/aor.json
# Validation succeeded: institutions/aor.json
# institutions/mps.json
# Validation succeeded: institutions/mps.json
# institutions/fmi.json
# Validation succeeded: institutions/fmi.json
# institutions/ureading.json
# Validation succeeded: institutions/ureading.json
# institutions/uobergen.json
# Validation succeeded: institutions/uobergen.json
# institutions/nasa-jpl.json
# Validation succeeded: institutions/nasa-jpl.json
# institutions/as-rcec.json
# Validation error: institutions/as-rcec.json None is not of type 'integer'
# institutions/niwa.json
# Validation succeeded: institutions/niwa.json
# institutions/uoleeds.json
# Validation succeeded: institutions/uoleeds.json
# institutions/uci.json
# Validation succeeded: institutions/uci.json
# institutions/kit.json
# Validation succeeded: institutions/kit.json
# institutions/osu.json
# Validation succeeded: institutions/osu.json
# institutions/mpi-b.json
# Validation succeeded: institutions/mpi-b.json
# institutions/issi.json
# Validation succeeded: institutions/issi.json
# institutions/jaxa.json
# Validation succeeded: institutions/jaxa.json
# institutions/uw.json
# Validation succeeded: institutions/uw.json
# institutions/lpc2e.json
# Validation succeeded: institutions/lpc2e.json
# institutions/ucsb.json
# Validation succeeded: institutions/ucsb.json
# institutions/ceda.json
# Validation succeeded: institutions/ceda.json
# institutions/ipsl.json
# Validation succeeded: institutions/ipsl.json

# %%
      
inst = glob.glob('consortia/*.json')

schema = {
  "$schema": "http://json-schema.org/draft-07/schema#",
  "title": "Consortium Data Schema",
  "type": "object",
  "properties": {
    "@id": {
      "type": "string",
      "pattern": "^mip-cmor-tables:organisations/consortia/.*$"
    },
    "@type": {
      "type": "string",
      "enum": ["cmip:consortium"]
    },
    "cmip_acronym": {
      "type": "string"
    },
    "description": {
      "type": "string"
    },
    "url": {
      "type": "string"
    },
    "changes": {
      "type": "string"
    },
    "members": {
      "type": "object",
      "properties": {
        "@set": {
          "type": "array",
          "items": {
            "type": "object",
            "properties": {
              "@id": {
                "type": "string"
              }
            },
            "required": ["@id"]
          }
        }
      },
      "required": ["@set"]
    }
  },
  "required": [
    "@id",
    "@type",
    "cmip_acronym",
    "description",
    "url",
    "changes",
    "members"
  ]
}


json.dump(schema,open('consortia/schema.json','w'),indent=4)


for iloc in inst:
    text = open(iloc,'r').read()
    textnew = text.replace('mip-cmor-tables/consortia','mip-cmor-tables:organisations/consortia')
    print(iloc)
    js = json.loads(textnew)
    # pprint.pprint(js)
    
    validate_json(js,schema,iloc)
    
    with open(f'./{iloc.lower()}','w') as f:
      jst = json.dumps(js,indent=4)
      f.write(jst)
      # os.system(f'rm {iloc}')
# Out:
# consortia/version.json
# Validation error: consortia/version.json [{'@id': '../../https://github.com/PCMDI/mip-cmor-tables/blob/main/JSONLD/organisations/consortia/solaris-heppa.json', '@type': 'version', 'version:file': '../../JSONLD/organisations/consortia/solaris-heppa.json', 'version:release': {'mip-cmor-tables': 'v6.5.0.2', 'cmip6plus': 'v6.5.1.4'}, 'version:previous_updates': 2, 'version:date': '2024-06-11T20:24:13+01:00', 'version:commit': {'hash': 'b619cb7885b6786c8f159b28616ddc51e8ad2744', 'message': 'update to solaris-heppa to link with institutions', 'author': {'name': 'Daniel Ellis', 'email': 'daniel.ellis@ext.esa.int'}}, 'version:data': {'@id': '../../mip-cmor-tables:organisations/consortia/solaris-heppa'}}] is not of type 'object'
# consortia/graph.json
# Validation error: consortia/graph.json 'cmip_acronym' is a required property
# consortia/frame.json
# Validation error: consortia/frame.json '@id' is a required property
# consortia/schema.json
# Validation error: consortia/schema.json '@id' is a required property
# consortia/solaris-heppa.json
# Validation error: consortia/solaris-heppa.json 'cmip_acronym' is a required property

# %%
consortia =  glob.glob('consortia/*.json')
      
inst = [i.replace('institutions/','').replace('.json','').lower() for i in glob.glob('institutions/*.json')]

# %%
for c in consortia:
    text = open(c,'r').read()
    if '@id' not in text or 'schema' in text: continue
    textnew = text.replace('mip-cmor-tables/consortia','mip-cmor-tables:organisations/consortia')
    js = json.loads(textnew)
    
    if 'members' not in js: continue
    
    members = js['members']
    
    
    newmembers = []
    for m in members:
        item = m['institution']['@id']
        
        if 'mip-cmor-tables:' in item:
            item = item.split('/')[-1]    
        
    
        
        if '(' in item:
            item = item.split('(')[0].strip()
        
        item = item.strip().split(' ')[0]
        item = f"mip-cmor-tables:organisations/institutions/{item.lower()}"
         
         
            
        if item.split('/')[-1] not in inst: 
            status = 'prior'
        else:
            status = 'active'
        
        
        print(item)
        
        newmembers.append({
            "@type":"consortia:member",
            'institution':{'@id': item},
            'membership_type':status,
            'dates':[{"from":2016, "to":2022, "phase":"CMIP6" }],
        })
            
       

    
    js.update({'members':{"@set":newmembers}, 
            'status':'active',})

    jsonld.expand(js)
    with open(c,'w') as f:
      jst = json.dumps(js,indent=4)
      f.write(jst)

# %%
# Out:
# [{'@type': 'consortia:member',
#   'consortia:institution': {'@id': 'mip-cmor-tables:organisations/institutions/NorESM'},
#   'consortia:membership_type': 'prior',
#   'consortia:dates': [{'from': 2016, 'to': 2022, 'phase': 'CMIP6'}]},
#  {'@type': 'consortia:member',
#   'consortia:institution': {'@id': 'mip-cmor-tables:organisations/institutions/MET-Norway'},
#   'consortia:membership_type': 'prior',
#   'consortia:dates': [{'from': 2016, 'to': 2022, 'phase': 'CMIP6'}]},
#  {'@type': 'consortia:member',
#   'consortia:institution': {'@id': 'mip-cmor-tables:organisations/institutions/NERSC'},
#   'consortia:membership_type': 'prior',
#   'consortia:dates': [{'from': 2016, 'to': 2022, 'phase': 'CMIP6'}]},
#  {'@type': 'consortia:member',
#   'consortia:institution': {'@id': 'mip-cmor-tables:organisations/institutions/NILU'},
#   'consortia:membership_type': 'prior',
#   'consortia:dates': [{'from': 2016, 'to': 2022, 'phase': 'CMIP6'}]},
#  {'@type': 'consortia:member',
#   'consortia:institution': {'@id': 'mip-cmor-tables:organisations/institutions/UiB'},
#   'consortia:membership_type': 'prior',
#   'consortia:dates': [{'from': 2016, 'to': 2022, 'phase': 'CMIP6'}]},
#  {'@type': 'consortia:member',
#   'consortia:institution': {'@id': 'mip-cmor-tables:organisations/institutions/UiO'},
#   'consortia:membership_type': 'prior',
#   'consortia:dates': [{'from': 2016, 'to': 2022, 'phase': 'CMIP6'}]},
#  {'@type': 'consortia:member',
#   'consortia:institution': {'@id': 'mip-cmor-tables:organisations/institutions/UNI'},
#   'consortia:membership_type': 'prior',
#   'consortia:dates': [{'from': 2016, 'to': 2022, 'phase': 'CMIP6'}]}]

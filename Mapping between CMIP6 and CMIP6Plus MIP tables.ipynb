# %% [markdown]
# # CMIP6Plus MIP table remapping
# To support the extension of CMIP6Plus variable set the CMIP6 variables have been reallocated to a set of tables named by their modelling domain, frequency and variable shape,
# e.g. atmos physical variables have moved from MIP table `Amon` to `APmon`, while atmospheric chemistry has moved to `ACmon` and aerosols to `AEmon`. Where data is on model levels `Lev` is appended to the table name.
#
# The code below constructs a dictionary to map the name of the CMIP6 variable to the CMIP6Plus equivalent

# %%
import json
import glob

# %% [markdown]
# Load table files and ignore coordinate and generic CV information

# %%
table_files = glob.glob('Tables/*')
json_files_to_ignore =  [
    'Tables/coordinate.json',
    'Tables/formula_terms.json',
    'Tables/generic_CV.json',
    'Tables/grids.json']
for i in json_files_to_ignore:
    table_files.remove(i)

# %% [markdown]
# Loop over variables and extract the CMIP6 variable name from the mip table entry and add to a dictionary

# %%
cmip6_to_cmip6plus_variable_mapping = {}
for table_filename in table_files:
    table = json.load(open(table_filename))
    table_id = table['Header']['table_id']
    for varname, details in table['variable_entry'].items():
        if 'CMIP6' in details['provenance']:
            cmip6_table_id = details['provenance']['CMIP6']['mip_table']
            cmip6_varname = details['provenance']['CMIP6']['variable_name']
            cmip6_to_cmip6plus_variable_mapping[(cmip6_table_id, cmip6_varname)] = (table_id, varname)

# %% [markdown]
# Print the result

# %%
print(' #{(CMIP6 MIP table, CMIP6 Variable name): (CMIP6Plus MIP table, CMIP6Plus Variable name)}')
cmip6_to_cmip6plus_variable_mapping
# Out:
#  #{(CMIP6 MIP table, CMIP6 Variable name): (CMIP6Plus MIP table, CMIP6Plus Variable name)}
# {('Emon', 'flashrate'): ('ACmon', 'flashrate'),
#  ('EmonZ', 'oxloss'): ('ACmonZ', 'oxloss'),
#  ('EmonZ', 'oxprod'): ('ACmonZ', 'oxprod'),
#  ('EmonZ', 'vmrox'): ('ACmonZ', 'vmrox'),
#  ('AERhr', 'sfno2'): ('AE1hr', 'sfno2'),
#  ('AERhr', 'sfo3'): ('AE1hr', 'sfo3'),
#  ('AERhr', 'sfpm25'): ('AE1hr', 'sfpm25'),
#  ('E3hrPt', 'rsdscsaf'): ('AE3hrPt', 'rsdscsaf'),
#  ('E3hrPt', 'rsdscsafbnd'): ('AE3hrPt', 'rsdscsafbnd'),
#  ('E3hrPt', 'rsuscsaf'): ('AE3hrPt', 'rsuscsaf'),
#  ('E3hrPt', 'rsuscsafbnd'): ('AE3hrPt', 'rsuscsafbnd'),
#  ('E3hrPt', 'rsutcsaf'): ('AE3hrPt', 'rsutcsaf'),
#  ('E3hrPt', 'rsdcsaf'): ('AE3hrPtLev', 'rsdcsaf'),
#  ('E3hrPt', 'rsdcsafbnd'): ('AE3hrPtLev', 'rsdcsafbnd'),
#  ('E3hrPt', 'rsucsaf'): ('AE3hrPtLev', 'rsucsaf'),
#  ('E3hrPt', 'rsucsafbnd'): ('AE3hrPtLev', 'rsucsafbnd'),
#  ('6hrPlev', 'bldep'): ('AE6hr', 'bldep'),
#  ('6hrPlevPt', 'zg500'): ('AE6hrPt', 'zg500'),
#  ('6hrLev', 'bs550aer'): ('AE6hrPtLev', 'bs550aer'),
#  ('6hrLev', 'ec550aer'): ('AE6hrPtLev', 'ec550aer'),
#  ('AERday', 'cod'): ('AEday', 'cod'),
#  ('AERday', 'maxpblz'): ('AEday', 'maxpblz'),
#  ('AERday', 'minpblz'): ('AEday', 'minpblz'),
#  ('AERday', 'od550aer'): ('AEday', 'od550aer'),
#  ('AERday', 'sfo3max'): ('AEday', 'sfo3max'),
#  ('AERday', 'toz'): ('AEday', 'toz'),
#  ('AERday', 'ua10'): ('AEday', 'ua10'),
#  ('AERday', 'zg10'): ('AEday', 'zg10'),
#  ('AERday', 'zg100'): ('AEday', 'zg100'),
#  ('AERday', 'zg500'): ('AEday', 'zg500'),
#  ('AERmon', 'abs550aer'): ('AEmon', 'abs550aer'),
#  ('AERmon', 'bldep'): ('AEmon', 'bldep'),
#  ('AERmon', 'ccn'): ('AEmon', 'ccn'),
#  ('AERmon', 'chepasoa'): ('AEmon', 'chepasoa'),
#  ('AERmon', 'chepsoa'): ('AEmon', 'chepsoa'),
#  ('AERmon', 'cltc'): ('AEmon', 'cltc'),
#  ('AERmon', 'cod'): ('AEmon', 'cod'),
#  ('Emon', 'depdust'): ('AEmon', 'depdust'),
#  ('AERmon', 'drybc'): ('AEmon', 'drybc'),
#  ('AERmon', 'drydust'): ('AEmon', 'drydust'),
#  ('AERmon', 'drynh3'): ('AEmon', 'drynh3'),
#  ('AERmon', 'drynh4'): ('AEmon', 'drynh4'),
#  ('AERmon', 'drynoy'): ('AEmon', 'drynoy'),
#  ('AERmon', 'dryo3'): ('AEmon', 'dryo3'),
#  ('AERmon', 'dryoa'): ('AEmon', 'dryoa'),
#  ('AERmon', 'dryso2'): ('AEmon', 'dryso2'),
#  ('AERmon', 'dryso4'): ('AEmon', 'dryso4'),
#  ('AERmon', 'dryss'): ('AEmon', 'dryss'),
#  ('AERmon', 'emiaco'): ('AEmon', 'emiaco'),
#  ('AERmon', 'emianox'): ('AEmon', 'emianox'),
#  ('AERmon', 'emiaoa'): ('AEmon', 'emiaoa'),
#  ('AERmon', 'emibc'): ('AEmon', 'emibc'),
#  ('AERmon', 'emibvoc'): ('AEmon', 'emibvoc'),
#  ('AERmon', 'emico'): ('AEmon', 'emico'),
#  ('AERmon', 'emidms'): ('AEmon', 'emidms'),
#  ('AERmon', 'emidust'): ('AEmon', 'emidust'),
#  ('AERmon', 'emiisop'): ('AEmon', 'emiisop'),
#  ('AERmon', 'eminh3'): ('AEmon', 'eminh3'),
#  ('AERmon', 'eminox'): ('AEmon', 'eminox'),
#  ('AERmon', 'emioa'): ('AEmon', 'emioa'),
#  ('AERmon', 'emiso2'): ('AEmon', 'emiso2'),
#  ('AERmon', 'emiso4'): ('AEmon', 'emiso4'),
#  ('AERmon', 'emiss'): ('AEmon', 'emiss'),
#  ('AERmon', 'emivoc'): ('AEmon', 'emivoc'),
#  ('AERmon', 'lwp'): ('AEmon', 'lwp'),
#  ('Emon', 'mmrno3'): ('AEmon', 'mmrno3'),
#  ('AERmon', 'od440aer'): ('AEmon', 'od440aer'),
#  ('AERmon', 'od550aer'): ('AEmon', 'od550aer'),
#  ('AERmon', 'od550aerh2o'): ('AEmon', 'od550aerh2o'),
#  ('AERmon', 'od550bb'): ('AEmon', 'od550bb'),
#  ('AERmon', 'od550bc'): ('AEmon', 'od550bc'),
#  ('AERmon', 'od550csaer'): ('AEmon', 'od550csaer'),
#  ('AERmon', 'od550dust'): ('AEmon', 'od550dust'),
#  ('AERmon', 'od550lt1aer'): ('AEmon', 'od550lt1aer'),
#  ('AERmon', 'od550no3'): ('AEmon', 'od550no3'),
#  ('AERmon', 'od550oa'): ('AEmon', 'od550oa'),
#  ('AERmon', 'od550so4'): ('AEmon', 'od550so4'),
#  ('AERmon', 'od550soa'): ('AEmon', 'od550soa'),
#  ('AERmon', 'od550ss'): ('AEmon', 'od550ss'),
#  ('AERmon', 'od870aer'): ('AEmon', 'od870aer'),
#  ('AERmon', 'pod0'): ('AEmon', 'pod0'),
#  ('AERmon', 'ptp'): ('AEmon', 'ptp'),
#  ('AERmon', 'reffclwtop'): ('AEmon', 'reffclwtop'),
#  ('AERmon', 'rlutaf'): ('AEmon', 'rlutaf'),
#  ('AERmon', 'rlutcsaf'): ('AEmon', 'rlutcsaf'),
#  ('AERmon', 'rsutaf'): ('AEmon', 'rsutaf'),
#  ('AERmon', 'rsutcsaf'): ('AEmon', 'rsutcsaf'),
#  ('Emon', 'sedustCI'): ('AEmon', 'sedustCI'),
#  ('AERmon', 'tatp'): ('AEmon', 'tatp'),
#  ('Emon', 'tntrl27'): ('AEmon', 'tntrl27'),
#  ('Emon', 'tntrs27'): ('AEmon', 'tntrs27'),
#  ('AERmon', 'toz'): ('AEmon', 'toz'),
#  ('AERmon', 'tropoz'): ('AEmon', 'tropoz'),
#  ('AERmon', 'ttop'): ('AEmon', 'ttop'),
#  ('AERmon', 'wetbc'): ('AEmon', 'wetbc'),
#  ('AERmon', 'wetdust'): ('AEmon', 'wetdust'),
#  ('AERmon', 'wetnh3'): ('AEmon', 'wetnh3'),
#  ('AERmon', 'wetnh4'): ('AEmon', 'wetnh4'),
#  ('AERmon', 'wetnoy'): ('AEmon', 'wetnoy'),
#  ('AERmon', 'wetoa'): ('AEmon', 'wetoa'),
#  ('AERmon', 'wetso2'): ('AEmon', 'wetso2'),
#  ('AERmon', 'wetso4'): ('AEmon', 'wetso4'),
#  ('AERmon', 'wetss'): ('AEmon', 'wetss'),
#  ('AERmon', 'ztp'): ('AEmon', 'ztp'),
#  ('AERmon', 'airmass'): ('AEmonLev', 'airmass'),
#  ('AERmon', 'aoanh'): ('AEmonLev', 'aoanh'),
#  ('AERmon', 'c2h2'): ('AEmonLev', 'c2h2'),
#  ('AERmon', 'c2h6'): ('AEmonLev', 'c2h6'),
#  ('AERmon', 'c3h6'): ('AEmonLev', 'c3h6'),
#  ('AERmon', 'c3h8'): ('AEmonLev', 'c3h8'),
#  ('AERmon', 'cdnc'): ('AEmonLev', 'cdnc'),
#  ('AERmon', 'ch3coch3'): ('AEmonLev', 'ch3coch3'),
#  ('AERmon', 'ch4'): ('AEmonLev', 'ch4'),
#  ('AERmon', 'cheaqpso4'): ('AEmonLev', 'cheaqpso4'),
#  ('AERmon', 'chegpso4'): ('AEmonLev', 'chegpso4'),
#  ('AERmon', 'co'): ('AEmonLev', 'co'),
#  ('AERmon', 'co2'): ('AEmonLev', 'co2'),
#  ('AERmon', 'dms'): ('AEmonLev', 'dms'),
#  ('Emon', 'ec550aer'): ('AEmonLev', 'ec550aer'),
#  ('AERmon', 'emilnox'): ('AEmonLev', 'emilnox'),
#  ('AERmon', 'h2o'): ('AEmonLev', 'h2o'),
#  ('AERmon', 'hcho'): ('AEmonLev', 'hcho'),
#  ('AERmon', 'hcl'): ('AEmonLev', 'hcl'),
#  ('AERmon', 'hno3'): ('AEmonLev', 'hno3'),
#  ('AERmon', 'isop'): ('AEmonLev', 'isop'),
#  ('AERmon', 'jno2'): ('AEmonLev', 'jno2'),
#  ('AERmon', 'lossch4'): ('AEmonLev', 'lossch4'),
#  ('AERmon', 'lossco'): ('AEmonLev', 'lossco'),
#  ('AERmon', 'lossn2o'): ('AEmonLev', 'lossn2o'),
#  ('AERmon', 'mmraerh2o'): ('AEmonLev', 'mmraerh2o'),
#  ('AERmon', 'mmrbc'): ('AEmonLev', 'mmrbc'),
#  ('AERmon', 'mmrdust'): ('AEmonLev', 'mmrdust'),
#  ('AERmon', 'mmrnh4'): ('AEmonLev', 'mmrnh4'),
#  ('AERmon', 'mmrno3'): ('AEmonLev', 'mmrno3'),
#  ('AERmon', 'mmroa'): ('AEmonLev', 'mmroa'),
#  ('AERmon', 'mmrpm1'): ('AEmonLev', 'mmrpm1'),
#  ('AERmon', 'mmrpm10'): ('AEmonLev', 'mmrpm10'),
#  ('AERmon', 'mmrpm2p5'): ('AEmonLev', 'mmrpm2p5'),
#  ('AERmon', 'mmrso4'): ('AEmonLev', 'mmrso4'),
#  ('AERmon', 'mmrsoa'): ('AEmonLev', 'mmrsoa'),
#  ('AERmon', 'mmrss'): ('AEmonLev', 'mmrss'),
#  ('AERmon', 'n2o'): ('AEmonLev', 'n2o'),
#  ('AERmon', 'nh50'): ('AEmonLev', 'nh50'),
#  ('AERmon', 'no'): ('AEmonLev', 'no'),
#  ('AERmon', 'no2'): ('AEmonLev', 'no2'),
#  ('AERmon', 'o3'): ('AEmonLev', 'o3'),
#  ('AERmon', 'o3loss'): ('AEmonLev', 'o3loss'),
#  ('AERmon', 'o3prod'): ('AEmonLev', 'o3prod'),
#  ('AERmon', 'o3ste'): ('AEmonLev', 'o3ste'),
#  ('AERmon', 'oh'): ('AEmonLev', 'oh'),
#  ('AERmon', 'pan'): ('AEmonLev', 'pan'),
#  ('AERmon', 'pfull'): ('AEmonLev', 'pfull'),
#  ('AERmon', 'phalf'): ('AEmonLev', 'phalf'),
#  ('AERmon', 'photo1d'): ('AEmonLev', 'photo1d'),
#  ('AERmon', 'so2'): ('AEmonLev', 'so2'),
#  ('AERmon', 'tntrl'): ('AEmonLev', 'tntrl'),
#  ('AERmon', 'tntrs'): ('AEmonLev', 'tntrs'),
#  ('AERmon', 'ua'): ('AEmonLev', 'ua'),
#  ('AERmon', 'va'): ('AEmonLev', 'va'),
#  ('AERmon', 'wa'): ('AEmonLev', 'wa'),
#  ('AERmonZ', 'bry'): ('AEmonZ', 'bry'),
#  ('AERmonZ', 'ch4'): ('AEmonZ', 'ch4'),
#  ('AERmonZ', 'cly'): ('AEmonZ', 'cly'),
#  ('AERmonZ', 'h2o'): ('AEmonZ', 'h2o'),
#  ('AERmonZ', 'hcl'): ('AEmonZ', 'hcl'),
#  ('AERmonZ', 'hno3'): ('AEmonZ', 'hno3'),
#  ('AERmonZ', 'ho2'): ('AEmonZ', 'ho2'),
#  ('AERmonZ', 'meanage'): ('AEmonZ', 'meanage'),
#  ('AERmonZ', 'n2o'): ('AEmonZ', 'n2o'),
#  ('AERmonZ', 'noy'): ('AEmonZ', 'noy'),
#  ('AERmonZ', 'o3'): ('AEmonZ', 'o3'),
#  ('AERmonZ', 'oh'): ('AEmonZ', 'oh'),
#  ('AERmonZ', 'ta'): ('AEmonZ', 'ta'),
#  ('EmonZ', 'tntrl'): ('AEmonZ', 'tntrl'),
#  ('EmonZ', 'tntrs'): ('AEmonZ', 'tntrs'),
#  ('AERmonZ', 'ua'): ('AEmonZ', 'ua'),
#  ('AERmonZ', 'va'): ('AEmonZ', 'va'),
#  ('AERmonZ', 'vt100'): ('AEmonZ', 'vt100'),
#  ('Esubhr', 'bldep'): ('AEsubhrPt', 'bldep'),
#  ('Esubhr', 'tntrl'): ('AEsubhrPtSite', 'tntrl'),
#  ('Esubhr', 'tntrs'): ('AEsubhrPtSite', 'tntrs'),
#  ('E1hr', 'pr'): ('AP1hr', 'pr'),
#  ('E1hr', 'prc'): ('AP1hr', 'prc'),
#  ('AERhr', 'ps'): ('AP1hr', 'ps'),
#  ('AERhr', 'tas'): ('AP1hr', 'tas'),
#  ('E1hr', 'psl'): ('AP1hrPt', 'psl'),
#  ('E1hr', 'rlut'): ('AP1hrPt', 'rlut'),
#  ('E1hr', 'ta'): ('AP1hrPt', 'ta'),
#  ('E1hr', 'ta27'): ('AP1hrPt', 'ta27'),
#  ('E1hr', 'tntr27'): ('AP1hrPt', 'tntr27'),
#  ('E1hr', 'ua'): ('AP1hrPt', 'ua'),
#  ('E1hr', 'ua27'): ('AP1hrPt', 'ua27'),
#  ('E1hr', 'utendnogw27'): ('AP1hrPt', 'utendnogw27'),
#  ('E1hr', 'va'): ('AP1hrPt', 'va'),
#  ('E1hr', 'va27'): ('AP1hrPt', 'va27'),
#  ('E1hr', 'vtendnogw27'): ('AP1hrPt', 'vtendnogw27'),
#  ('E1hr', 'wap'): ('AP1hrPt', 'wap'),
#  ('E1hr', 'wap27'): ('AP1hrPt', 'wap27'),
#  ('E1hr', 'zg27'): ('AP1hrPt', 'zg27'),
#  ('E3hr', 'clivi'): ('AP3hr', 'clivi'),
#  ('3hr', 'clt'): ('AP3hr', 'clt'),
#  ('E3hr', 'clwvi'): ('AP3hr', 'clwvi'),
#  ('3hr', 'hfls'): ('AP3hr', 'hfls'),
#  ('3hr', 'hfss'): ('AP3hr', 'hfss'),
#  ('3hr', 'pr'): ('AP3hr', 'pr'),
#  ('3hr', 'prc'): ('AP3hr', 'prc'),
#  ('E3hr', 'prcsh'): ('AP3hr', 'prcsh'),
#  ('E3hr', 'prra'): ('AP3hr', 'prra'),
#  ('E3hr', 'prrc'): ('AP3hr', 'prrc'),
#  ('3hr', 'prsn'): ('AP3hr', 'prsn'),
#  ('E3hr', 'prsnc'): ('AP3hr', 'prsnc'),
#  ('E3hr', 'prw'): ('AP3hr', 'prw'),
#  ('E3hr', 'psl'): ('AP3hr', 'psl'),
#  ('3hr', 'rlds'): ('AP3hr', 'rlds'),
#  ('3hr', 'rldscs'): ('AP3hr', 'rldscs'),
#  ('3hr', 'rlus'): ('AP3hr', 'rlus'),
#  ('E3hr', 'rlut'): ('AP3hr', 'rlut'),
#  ('E3hr', 'rlutcs'): ('AP3hr', 'rlutcs'),
#  ('3hr', 'rsds'): ('AP3hr', 'rsds'),
#  ('3hr', 'rsdscs'): ('AP3hr', 'rsdscs'),
#  ('3hr', 'rsdsdiff'): ('AP3hr', 'rsdsdiff'),
#  ('E3hr', 'rsdt'): ('AP3hr', 'rsdt'),
#  ('3hr', 'rsus'): ('AP3hr', 'rsus'),
#  ('3hr', 'rsuscs'): ('AP3hr', 'rsuscs'),
#  ('E3hr', 'rsut'): ('AP3hr', 'rsut'),
#  ('E3hr', 'rsutcs'): ('AP3hr', 'rsutcs'),
#  ('E3hr', 'sfcWind'): ('AP3hr', 'sfcWind'),
#  ('E3hr', 'uas'): ('AP3hr', 'uas'),
#  ('E3hr', 'vas'): ('AP3hr', 'vas'),
#  ('E3hrPt', 'albdiffbnd'): ('AP3hrPt', 'albdiffbnd'),
#  ('E3hrPt', 'albdirbnd'): ('AP3hrPt', 'albdirbnd'),
#  ('E3hrPt', 'cfadDbze94'): ('AP3hrPt', 'cfadDbze94'),
#  ('E3hrPt', 'cfadLidarsr532'): ('AP3hrPt', 'cfadLidarsr532'),
#  ('CF3hr', 'ci'): ('AP3hrPt', 'ci'),
#  ('E3hrPt', 'clcalipso'): ('AP3hrPt', 'clcalipso'),
#  ('E3hrPt', 'clcalipso2'): ('AP3hrPt', 'clcalipso2'),
#  ('E3hrPt', 'clhcalipso'): ('AP3hrPt', 'clhcalipso'),
#  ('E3hrPt', 'clisccp'): ('AP3hrPt', 'clisccp'),
#  ('CF3hr', 'clivi'): ('AP3hrPt', 'clivi'),
#  ('E3hrPt', 'cllcalipso'): ('AP3hrPt', 'cllcalipso'),
#  ('E3hrPt', 'clmcalipso'): ('AP3hrPt', 'clmcalipso'),
#  ('E3hrPt', 'clmisr'): ('AP3hrPt', 'clmisr'),
#  ('CF3hr', 'clt'): ('AP3hrPt', 'clt'),
#  ('CF3hr', 'cltc'): ('AP3hrPt', 'cltc'),
#  ('E3hrPt', 'cltcalipso'): ('AP3hrPt', 'cltcalipso'),
#  ('CF3hr', 'clwvi'): ('AP3hrPt', 'clwvi'),
#  ('CF3hr', 'evspsbl'): ('AP3hrPt', 'evspsbl'),
#  ('CF3hr', 'hfls'): ('AP3hrPt', 'hfls'),
#  ('CF3hr', 'hfss'): ('AP3hrPt', 'hfss'),
#  ('CF3hr', 'hurs'): ('AP3hrPt', 'hurs'),
#  ('E3hrPt', 'hus7h'): ('AP3hrPt', 'hus7h'),
#  ('3hr', 'huss'): ('AP3hrPt', 'huss'),
#  ('E3hrPt', 'jpdftaureicemodis'): ('AP3hrPt', 'jpdftaureicemodis'),
#  ('E3hrPt', 'jpdftaureliqmodis'): ('AP3hrPt', 'jpdftaureliqmodis'),
#  ('E3hrPt', 'parasolRefl'): ('AP3hrPt', 'parasolRefl'),
#  ('CF3hr', 'pr'): ('AP3hrPt', 'pr'),
#  ('CF3hr', 'prc'): ('AP3hrPt', 'prc'),
#  ('CF3hr', 'prsn'): ('AP3hrPt', 'prsn'),
#  ('CF3hr', 'prw'): ('AP3hrPt', 'prw'),
#  ('3hr', 'ps'): ('AP3hrPt', 'ps'),
#  ('CF3hr', 'psl'): ('AP3hrPt', 'psl'),
#  ('CF3hr', 'rlds'): ('AP3hrPt', 'rlds'),
#  ('CF3hr', 'rldscs'): ('AP3hrPt', 'rldscs'),
#  ('CF3hr', 'rlus'): ('AP3hrPt', 'rlus'),
#  ('CF3hr', 'rlut'): ('AP3hrPt', 'rlut'),
#  ('CF3hr', 'rlutcs'): ('AP3hrPt', 'rlutcs'),
#  ('CF3hr', 'rsds'): ('AP3hrPt', 'rsds'),
#  ('CF3hr', 'rsdscs'): ('AP3hrPt', 'rsdscs'),
#  ('E3hrPt', 'rsdscsbnd'): ('AP3hrPt', 'rsdscsbnd'),
#  ('CF3hr', 'rsdt'): ('AP3hrPt', 'rsdt'),
#  ('CF3hr', 'rsus'): ('AP3hrPt', 'rsus'),
#  ('CF3hr', 'rsuscs'): ('AP3hrPt', 'rsuscs'),
#  ('E3hrPt', 'rsuscsbnd'): ('AP3hrPt', 'rsuscsbnd'),
#  ('CF3hr', 'rsut'): ('AP3hrPt', 'rsut'),
#  ('CF3hr', 'rsutcs'): ('AP3hrPt', 'rsutcs'),
#  ('E3hrPt', 'rsutcsafbnd'): ('AP3hrPt', 'rsutcsafbnd'),
#  ('E3hrPt', 'rsutcsbnd'): ('AP3hrPt', 'rsutcsbnd'),
#  ('CF3hr', 'rtmt'): ('AP3hrPt', 'rtmt'),
#  ('CF3hr', 'sci'): ('AP3hrPt', 'sci'),
#  ('CF3hr', 'sfcWind'): ('AP3hrPt', 'sfcWind'),
#  ('E3hrPt', 'solbnd'): ('AP3hrPt', 'solbnd'),
#  ('E3hrPt', 'sza'): ('AP3hrPt', 'sza'),
#  ('E3hrPt', 'ta7h'): ('AP3hrPt', 'ta7h'),
#  ('3hr', 'tas'): ('AP3hrPt', 'tas'),
#  ('CF3hr', 'tauu'): ('AP3hrPt', 'tauu'),
#  ('CF3hr', 'tauv'): ('AP3hrPt', 'tauv'),
#  ('CF3hr', 'ts'): ('AP3hrPt', 'ts'),
#  ('E3hrPt', 'ua7h'): ('AP3hrPt', 'ua7h'),
#  ('3hr', 'uas'): ('AP3hrPt', 'uas'),
#  ('E3hrPt', 'va7h'): ('AP3hrPt', 'va7h'),
#  ('3hr', 'vas'): ('AP3hrPt', 'vas'),
#  ('E3hrPt', 'wap7h'): ('AP3hrPt', 'wap7h'),
#  ('E3hrPt', 'aerasymbnd'): ('AP3hrPtLev', 'aerasymbnd'),
#  ('E3hrPt', 'aeroptbnd'): ('AP3hrPtLev', 'aeroptbnd'),
#  ('E3hrPt', 'aerssabnd'): ('AP3hrPtLev', 'aerssabnd'),
#  ('E3hrPt', 'ch4'): ('AP3hrPtLev', 'ch4'),
#  ('CF3hr', 'clc'): ('AP3hrPtLev', 'clc'),
#  ('CF3hr', 'clic'): ('AP3hrPtLev', 'clic'),
#  ('CF3hr', 'clis'): ('AP3hrPtLev', 'clis'),
#  ('CF3hr', 'cls'): ('AP3hrPtLev', 'cls'),
#  ('CF3hr', 'clwc'): ('AP3hrPtLev', 'clwc'),
#  ('CF3hr', 'clws'): ('AP3hrPtLev', 'clws'),
#  ('E3hrPt', 'co2'): ('AP3hrPtLev', 'co2'),
#  ('CF3hr', 'demc'): ('AP3hrPtLev', 'demc'),
#  ('CF3hr', 'dems'): ('AP3hrPtLev', 'dems'),
#  ('CF3hr', 'dtauc'): ('AP3hrPtLev', 'dtauc'),
#  ('CF3hr', 'dtaus'): ('AP3hrPtLev', 'dtaus'),
#  ('CF3hr', 'grpllsprof'): ('AP3hrPtLev', 'grpllsprof'),
#  ('CF3hr', 'h2o'): ('AP3hrPtLev', 'h2o'),
#  ('E3hrPt', 'hus'): ('AP3hrPtLev', 'hus'),
#  ('E3hrPt', 'n2o'): ('AP3hrPtLev', 'n2o'),
#  ('E3hrPt', 'o3'): ('AP3hrPtLev', 'o3'),
#  ('CF3hr', 'pfull'): ('AP3hrPtLev', 'pfull'),
#  ('CF3hr', 'phalf'): ('AP3hrPtLev', 'phalf'),
#  ('CF3hr', 'prcprof'): ('AP3hrPtLev', 'prcprof'),
#  ('CF3hr', 'prlsns'): ('AP3hrPtLev', 'prlsns'),
#  ('CF3hr', 'prlsprof'): ('AP3hrPtLev', 'prlsprof'),
#  ('CF3hr', 'prsnc'): ('AP3hrPtLev', 'prsnc'),
#  ('CF3hr', 'reffclic'): ('AP3hrPtLev', 'reffclic'),
#  ('CF3hr', 'reffclis'): ('AP3hrPtLev', 'reffclis'),
#  ('CF3hr', 'reffclwc'): ('AP3hrPtLev', 'reffclwc'),
#  ('CF3hr', 'reffclws'): ('AP3hrPtLev', 'reffclws'),
#  ('CF3hr', 'reffgrpls'): ('AP3hrPtLev', 'reffgrpls'),
#  ('CF3hr', 'reffrainc'): ('AP3hrPtLev', 'reffrainc'),
#  ('CF3hr', 'reffrains'): ('AP3hrPtLev', 'reffrains'),
#  ('CF3hr', 'reffsnowc'): ('AP3hrPtLev', 'reffsnowc'),
#  ('CF3hr', 'reffsnows'): ('AP3hrPtLev', 'reffsnows'),
#  ('E3hrPt', 'rsdcs'): ('AP3hrPtLev', 'rsdcs'),
#  ('E3hrPt', 'rsdcsbnd'): ('AP3hrPtLev', 'rsdcsbnd'),
#  ('E3hrPt', 'rsucs'): ('AP3hrPtLev', 'rsucs'),
#  ('E3hrPt', 'rsucsbnd'): ('AP3hrPtLev', 'rsucsbnd'),
#  ('CF3hr', 'ta'): ('AP3hrPtLev', 'ta'),
#  ('CF3hr', 'zfull'): ('AP3hrPtLev', 'zfull'),
#  ('CF3hr', 'zhalf'): ('AP3hrPtLev', 'zhalf'),
#  ('6hrPlev', 'hurs'): ('AP6hr', 'hurs'),
#  ('6hrPlev', 'hus4'): ('AP6hr', 'hus4'),
#  ('6hrPlev', 'pr'): ('AP6hr', 'pr'),
#  ('6hrPlev', 'prhmax'): ('AP6hr', 'prhmax'),
#  ('6hrPlev', 'psl'): ('AP6hr', 'psl'),
#  ('6hrPlev', 'rv850'): ('AP6hr', 'rv850'),
#  ('6hrPlev', 'sfcWind'): ('AP6hr', 'sfcWind'),
#  ('6hrPlev', 'tas'): ('AP6hr', 'tas'),
#  ('6hrPlev', 'ua100m'): ('AP6hr', 'ua100m'),
#  ('6hrPlev', 'uas'): ('AP6hr', 'uas'),
#  ('6hrPlev', 'va100m'): ('AP6hr', 'va100m'),
#  ('6hrPlev', 'vas'): ('AP6hr', 'vas'),
#  ('6hrPlev', 'wap4'): ('AP6hr', 'wap4'),
#  ('6hrPlev', 'wsgmax100m'): ('AP6hr', 'wsgmax100m'),
#  ('6hrPlev', 'wsgmax10m'): ('AP6hr', 'wsgmax10m'),
#  ('6hrPlev', 'zg1000'): ('AP6hr', 'zg1000'),
#  ('6hrPlevPt', 'cldicemxrat27'): ('AP6hrPt', 'cldicemxrat27'),
#  ('6hrPlevPt', 'cldwatmxrat27'): ('AP6hrPt', 'cldwatmxrat27'),
#  ('6hrPlevPt', 'dtauc'): ('AP6hrPt', 'dtauc'),
#  ('6hrPlevPt', 'dtaus'): ('AP6hrPt', 'dtaus'),
#  ('6hrPlevPt', 'grplmxrat27'): ('AP6hrPt', 'grplmxrat27'),
#  ('6hrPlevPt', 'hus27'): ('AP6hrPt', 'hus27'),
#  ('6hrPlevPt', 'hus7h'): ('AP6hrPt', 'hus7h'),
#  ('6hrPlevPt', 'huss'): ('AP6hrPt', 'huss'),
#  ('6hrPlevPt', 'lwsffluxaero'): ('AP6hrPt', 'lwsffluxaero'),
#  ('6hrPlevPt', 'lwtoafluxaerocs'): ('AP6hrPt', 'lwtoafluxaerocs'),
#  ('6hrLev', 'ps'): ('AP6hrPt', 'ps'),
#  ('6hrPlevPt', 'psl'): ('AP6hrPt', 'psl'),
#  ('6hrPlevPt', 'rainmxrat27'): ('AP6hrPt', 'rainmxrat27'),
#  ('6hrPlevPt', 'rv850'): ('AP6hrPt', 'rv850'),
#  ('6hrPlevPt', 'sfcWind'): ('AP6hrPt', 'sfcWind'),
#  ('6hrPlevPt', 'snowmxrat27'): ('AP6hrPt', 'snowmxrat27'),
#  ('6hrPlevPt', 'swsffluxaero'): ('AP6hrPt', 'swsffluxaero'),
#  ('6hrPlevPt', 'swtoafluxaerocs'): ('AP6hrPt', 'swtoafluxaerocs'),
#  ('6hrPlevPt', 'ta'): ('AP6hrPt', 'ta'),
#  ('6hrPlevPt', 'ta27'): ('AP6hrPt', 'ta27'),
#  ('6hrPlevPt', 'ta7h'): ('AP6hrPt', 'ta7h'),
#  ('6hrPlevPt', 'tas'): ('AP6hrPt', 'tas'),
#  ('6hrPlevPt', 'ts'): ('AP6hrPt', 'ts'),
#  ('6hrPlevPt', 'ua'): ('AP6hrPt', 'ua'),
#  ('6hrPlevPt', 'ua7h'): ('AP6hrPt', 'ua7h'),
#  ('6hrPlevPt', 'uas'): ('AP6hrPt', 'uas'),
#  ('6hrPlevPt', 'va'): ('AP6hrPt', 'va'),
#  ('6hrPlevPt', 'va7h'): ('AP6hrPt', 'va7h'),
#  ('6hrPlevPt', 'vas'): ('AP6hrPt', 'vas'),
#  ('6hrPlevPt', 'vortmean'): ('AP6hrPt', 'vortmean'),
#  ('6hrPlevPt', 'wbptemp7h'): ('AP6hrPt', 'wbptemp7h'),
#  ('6hrPlevPt', 'zg27'): ('AP6hrPt', 'zg27'),
#  ('6hrPlevPt', 'zg7h'): ('AP6hrPt', 'zg7h'),
#  ('6hrLev', 'hus'): ('AP6hrPtLev', 'hus'),
#  ('6hrLev', 'pfull'): ('AP6hrPtLev', 'pfull'),
#  ('6hrLev', 'ta'): ('AP6hrPtLev', 'ta'),
#  ('6hrLev', 'ua'): ('AP6hrPtLev', 'ua'),
#  ('6hrLev', 'va'): ('AP6hrPtLev', 'va'),
#  ('E6hrZ', 'zmlwaero'): ('AP6hrPtZ', 'zmlwaero'),
#  ('E6hrZ', 'zmswaero'): ('AP6hrPtZ', 'zmswaero'),
#  ('CFday', 'albisccp'): ('APday', 'albisccp'),
#  ('Eday', 'aod550volso4'): ('APday', 'aod550volso4'),
#  ('CFday', 'ccb'): ('APday', 'ccb'),
#  ('Eday', 'ccldncl'): ('APday', 'ccldncl'),
#  ('CFday', 'cct'): ('APday', 'cct'),
#  ('CFday', 'clcalipso'): ('APday', 'clcalipso'),
#  ('Eday', 'cldnci'): ('APday', 'cldnci'),
#  ('Eday', 'cldnvi'): ('APday', 'cldnvi'),
#  ('CFday', 'clhcalipso'): ('APday', 'clhcalipso'),
#  ('CFday', 'clisccp'): ('APday', 'clisccp'),
#  ('CFday', 'clivi'): ('APday', 'clivi'),
#  ('Eday', 'clivic'): ('APday', 'clivic'),
#  ('CFday', 'cllcalipso'): ('APday', 'cllcalipso'),
#  ('CFday', 'clmcalipso'): ('APday', 'clmcalipso'),
#  ('day', 'clt'): ('APday', 'clt'),
#  ('CFday', 'cltcalipso'): ('APday', 'cltcalipso'),
#  ('CFday', 'cltisccp'): ('APday', 'cltisccp'),
#  ('CFday', 'clwvi'): ('APday', 'clwvi'),
#  ('Eday', 'clwvic'): ('APday', 'clwvic'),
#  ('Eday', 'hfdsl'): ('APday', 'hfdsl'),
#  ('Eday', 'hfdsnb'): ('APday', 'hfdsnb'),
#  ('day', 'hfls'): ('APday', 'hfls'),
#  ('Eday', 'hfmlt'): ('APday', 'hfmlt'),
#  ('Eday', 'hfrs'): ('APday', 'hfrs'),
#  ('Eday', 'hfsbl'): ('APday', 'hfsbl'),
#  ('day', 'hfss'): ('APday', 'hfss'),
#  ('day', 'hur'): ('APday', 'hur'),
#  ('day', 'hurs'): ('APday', 'hurs'),
#  ('day', 'hursmax'): ('APday', 'hursmax'),
#  ('day', 'hursmin'): ('APday', 'hursmin'),
#  ('Eday', 'hursminCrop'): ('APday', 'hursminCrop'),
#  ('Eday', 'hus'): ('APday', 'hus19'),
#  ('day', 'hus'): ('APday', 'hus8'),
#  ('Eday', 'hus850'): ('APday', 'hus850'),
#  ('day', 'huss'): ('APday', 'huss'),
#  ('Eday', 'jpdftaureicemodis'): ('APday', 'jpdftaureicemodis'),
#  ('Eday', 'jpdftaureliqmodis'): ('APday', 'jpdftaureliqmodis'),
#  ('Eday', 'loadbc'): ('APday', 'loadbc'),
#  ('Eday', 'loaddust'): ('APday', 'loaddust'),
#  ('Eday', 'loadnh4'): ('APday', 'loadnh4'),
#  ('Eday', 'loadno3'): ('APday', 'loadno3'),
#  ('Eday', 'loadoa'): ('APday', 'loadoa'),
#  ('Eday', 'loadpoa'): ('APday', 'loadpoa'),
#  ('Eday', 'loadso4'): ('APday', 'loadso4'),
#  ('Eday', 'loadsoa'): ('APday', 'loadsoa'),
#  ('Eday', 'loadss'): ('APday', 'loadss'),
#  ('Eday', 'parasolRefl'): ('APday', 'parasolRefl'),
#  ('CFday', 'pctisccp'): ('APday', 'pctisccp'),
#  ('day', 'pr'): ('APday', 'pr'),
#  ('Eday', 'prCrop'): ('APday', 'prCrop'),
#  ('day', 'prc'): ('APday', 'prc'),
#  ('Eday', 'prhmax'): ('APday', 'prhmax'),
#  ('Eday', 'prra'): ('APday', 'prra'),
#  ('Eday', 'prrc'): ('APday', 'prrc'),
#  ('Eday', 'prrsn'): ('APday', 'prrsn'),
#  ('day', 'prsn'): ('APday', 'prsn'),
#  ('Eday', 'prsnc'): ('APday', 'prsnc'),
#  ('Eday', 'prsnsn'): ('APday', 'prsnsn'),
#  ('Eday', 'prw'): ('APday', 'prw'),
#  ('CFday', 'ps'): ('APday', 'ps'),
#  ('day', 'psl'): ('APday', 'psl'),
#  ('Eday', 'reffcclwtop'): ('APday', 'reffcclwtop'),
#  ('Eday', 'reffsclwtop'): ('APday', 'reffsclwtop'),
#  ('day', 'rlds'): ('APday', 'rlds'),
#  ('CFday', 'rldscs'): ('APday', 'rldscs'),
#  ('day', 'rls'): ('APday', 'rls'),
#  ('day', 'rlus'): ('APday', 'rlus'),
#  ('day', 'rlut'): ('APday', 'rlut'),
#  ('CFday', 'rlutcs'): ('APday', 'rlutcs'),
#  ('day', 'rsds'): ('APday', 'rsds'),
#  ('CFday', 'rsdscs'): ('APday', 'rsdscs'),
#  ('Eday', 'rsdscsdiff'): ('APday', 'rsdscsdiff'),
#  ('Eday', 'rsdsdiff'): ('APday', 'rsdsdiff'),
#  ('CFday', 'rsdt'): ('APday', 'rsdt'),
#  ('day', 'rss'): ('APday', 'rss'),
#  ('day', 'rsus'): ('APday', 'rsus'),
#  ('CFday', 'rsuscs'): ('APday', 'rsuscs'),
#  ('CFday', 'rsut'): ('APday', 'rsut'),
#  ('CFday', 'rsutcs'): ('APday', 'rsutcs'),
#  ('Eday', 'sblnosn'): ('APday', 'sblnosn'),
#  ('Eday', 'scldncl'): ('APday', 'scldncl'),
#  ('day', 'sfcWind'): ('APday', 'sfcWind'),
#  ('day', 'sfcWindmax'): ('APday', 'sfcWindmax'),
#  ('Eday', 'snmsl'): ('APday', 'snmsl'),
#  ('Eday', 'snrefr'): ('APday', 'snrefr'),
#  ('Eday', 'snwc'): ('APday', 'snwc'),
#  ('Eday', 'ta'): ('APday', 'ta19'),
#  ('Eday', 'ta500'): ('APday', 'ta500'),
#  ('CFday', 'ta700'): ('APday', 'ta700'),
#  ('day', 'ta'): ('APday', 'ta8'),
#  ('Eday', 'ta850'): ('APday', 'ta850'),
#  ('day', 'tas'): ('APday', 'tas'),
#  ('day', 'tasmax'): ('APday', 'tasmax'),
#  ('Eday', 'tasmaxCrop'): ('APday', 'tasmaxCrop'),
#  ('day', 'tasmin'): ('APday', 'tasmin'),
#  ('Eday', 'tasminCrop'): ('APday', 'tasminCrop'),
#  ('Eday', 'tau'): ('APday', 'tau'),
#  ('Eday', 'tauu'): ('APday', 'tauu'),
#  ('Eday', 'tauupbl'): ('APday', 'tauupbl'),
#  ('Eday', 'tauv'): ('APday', 'tauv'),
#  ('Eday', 'tauvpbl'): ('APday', 'tauvpbl'),
#  ('Eday', 'tdps'): ('APday', 'tdps'),
#  ('Eday', 'tr'): ('APday', 'tr'),
#  ('Eday', 'ts'): ('APday', 'ts'),
#  ('Eday', 'tsland'): ('APday', 'tsland'),
#  ('Eday', 'tsns'): ('APday', 'tsns'),
#  ('Eday', 'ua'): ('APday', 'ua19'),
#  ('day', 'ua'): ('APday', 'ua8'),
#  ('day', 'uas'): ('APday', 'uas'),
#  ('Eday', 'va'): ('APday', 'va19'),
#  ('day', 'va'): ('APday', 'va8'),
#  ('day', 'vas'): ('APday', 'vas'),
#  ('Eday', 'wap'): ('APday', 'wap19'),
#  ('CFday', 'wap500'): ('APday', 'wap500'),
#  ('day', 'wap'): ('APday', 'wap8'),
#  ('AERday', 'zg1000'): ('APday', 'zg1000'),
#  ('Eday', 'zg'): ('APday', 'zg19'),
#  ('day', 'zg'): ('APday', 'zg8'),
#  ('Eday', 'zmla'): ('APday', 'zmla'),
#  ('CFday', 'cl'): ('APdayLev', 'cl'),
#  ('CFday', 'cli'): ('APdayLev', 'cli'),
#  ('CFday', 'clw'): ('APdayLev', 'clw'),
#  ('CFday', 'hur'): ('APdayLev', 'hur'),
#  ('CFday', 'hus'): ('APdayLev', 'hus'),
#  ('CFday', 'mc'): ('APdayLev', 'mc'),
#  ('CFday', 'pfull'): ('APdayLev', 'pfull'),
#  ('CFday', 'phalf'): ('APdayLev', 'phalf'),
#  ('CFday', 'ta'): ('APdayLev', 'ta'),
#  ('CFday', 'ua'): ('APdayLev', 'ua'),
#  ('CFday', 'va'): ('APdayLev', 'va'),
#  ('CFday', 'wap'): ('APdayLev', 'wap'),
#  ('CFday', 'zg'): ('APdayLev', 'zg'),
#  ('EdayZ', 'epfy'): ('APdayZ', 'epfy'),
#  ('EdayZ', 'epfz'): ('APdayZ', 'epfz'),
#  ('EdayZ', 'hus'): ('APdayZ', 'hus'),
#  ('EdayZ', 'psitem'): ('APdayZ', 'psitem'),
#  ('EdayZ', 'ta'): ('APdayZ', 'ta'),
#  ('EdayZ', 'ua'): ('APdayZ', 'ua'),
#  ('EdayZ', 'utendepfd'): ('APdayZ', 'utendepfd'),
#  ('EdayZ', 'utendnogw'): ('APdayZ', 'utendnogw'),
#  ('EdayZ', 'utendogw'): ('APdayZ', 'utendogw'),
#  ('EdayZ', 'utendvtem'): ('APdayZ', 'utendvtem'),
#  ('EdayZ', 'utendwtem'): ('APdayZ', 'utendwtem'),
#  ('EdayZ', 'va'): ('APdayZ', 'va'),
#  ('EdayZ', 'vtem'): ('APdayZ', 'vtem'),
#  ('EdayZ', 'wtem'): ('APdayZ', 'wtem'),
#  ('EdayZ', 'zg'): ('APdayZ', 'zg'),
#  ('fx', 'areacella'): ('APfx', 'areacella'),
#  ('Efx', 'ps'): ('APfx', 'ps'),
#  ('Efx', 'rld'): ('APfx', 'rld'),
#  ('Efx', 'rlu'): ('APfx', 'rlu'),
#  ('Efx', 'rsd'): ('APfx', 'rsd'),
#  ('Efx', 'rsu'): ('APfx', 'rsu'),
#  ('fx', 'sftlf'): ('APfx', 'sftlf'),
#  ('Efx', 'siltfrac'): ('APfx', 'siltfrac'),
#  ('fx', 'zfull'): ('APfx', 'zfull'),
#  ('CFmon', 'albisccp'): ('APmon', 'albisccp'),
#  ('Amon', 'ccb'): ('APmon', 'ccb'),
#  ('Amon', 'cct'): ('APmon', 'cct'),
#  ('Emon', 'cfadDbze94'): ('APmon', 'cfadDbze94'),
#  ('Emon', 'cfadLidarsr532'): ('APmon', 'cfadLidarsr532'),
#  ('Amon', 'cfc113global'): ('APmon', 'cfc113global'),
#  ('Amon', 'cfc11global'): ('APmon', 'cfc11global'),
#  ('Amon', 'cfc12global'): ('APmon', 'cfc12global'),
#  ('Amon', 'ch4'): ('APmon', 'ch4'),
#  ('Amon', 'ch4global'): ('APmon', 'ch4global'),
#  ('Amon', 'ci'): ('APmon', 'ci'),
#  ('CFmon', 'clcalipso'): ('APmon', 'clcalipso'),
#  ('Emon', 'clcalipsoice'): ('APmon', 'clcalipsoice'),
#  ('Emon', 'clcalipsoliq'): ('APmon', 'clcalipsoliq'),
#  ('Emon', 'cldicemxrat27'): ('APmon', 'cldicemxrat27'),
#  ('Emon', 'cldnci'): ('APmon', 'cldnci'),
#  ('Emon', 'cldncl'): ('APmon', 'cldncl'),
#  ('Emon', 'cldnvi'): ('APmon', 'cldnvi'),
#  ('Emon', 'cldwatmxrat27'): ('APmon', 'cldwatmxrat27'),
#  ('CFmon', 'clhcalipso'): ('APmon', 'clhcalipso'),
#  ('Emon', 'climodis'): ('APmon', 'climodis'),
#  ('CFmon', 'clisccp'): ('APmon', 'clisccp'),
#  ('Amon', 'clivi'): ('APmon', 'clivi'),
#  ('CFmon', 'cllcalipso'): ('APmon', 'cllcalipso'),
#  ('CFmon', 'clmcalipso'): ('APmon', 'clmcalipso'),
#  ('Emon', 'clmisr'): ('APmon', 'clmisr'),
#  ('Amon', 'clt'): ('APmon', 'clt'),
#  ('CFmon', 'cltcalipso'): ('APmon', 'cltcalipso'),
#  ('CFmon', 'cltisccp'): ('APmon', 'cltisccp'),
#  ('Emon', 'cltmodis'): ('APmon', 'cltmodis'),
#  ('Emon', 'clwmodis'): ('APmon', 'clwmodis'),
#  ('Amon', 'clwvi'): ('APmon', 'clwvi'),
#  ('Emon', 'clwvic'): ('APmon', 'clwvic'),
#  ('Amon', 'co2'): ('APmon', 'co2'),
#  ('Amon', 'co2mass'): ('APmon', 'co2mass'),
#  ('Emon', 'co2s'): ('APmon', 'co2s'),
#  ('Emon', 'columnmassflux'): ('APmon', 'columnmassflux'),
#  ('Emon', 'diabdrag'): ('APmon', 'diabdrag'),
#  ('Amon', 'evspsbl'): ('APmon', 'evspsbl'),
#  ('Amon', 'fco2antt'): ('APmon', 'fco2antt'),
#  ('Amon', 'fco2fos'): ('APmon', 'fco2fos'),
#  ('Amon', 'fco2nat'): ('APmon', 'fco2nat'),
#  ('Emon', 'grplmxrat27'): ('APmon', 'grplmxrat27'),
#  ('Amon', 'hcfc22global'): ('APmon', 'hcfc22global'),
#  ('Amon', 'hfls'): ('APmon', 'hfls'),
#  ('Amon', 'hfss'): ('APmon', 'hfss'),
#  ('Amon', 'hur'): ('APmon', 'hur'),
#  ('Amon', 'hurs'): ('APmon', 'hurs'),
#  ('Emon', 'hursminCrop'): ('APmon', 'hursminCrop'),
#  ('Amon', 'hus'): ('APmon', 'hus19'),
#  ('Emon', 'hus27'): ('APmon', 'hus27'),
#  ('Emon', 'hus'): ('APmon', 'hus7h'),
#  ('Amon', 'huss'): ('APmon', 'huss'),
#  ('Emon', 'intuadse'): ('APmon', 'intuadse'),
#  ('Emon', 'intuaw'): ('APmon', 'intuaw'),
#  ('Emon', 'intvadse'): ('APmon', 'intvadse'),
#  ('Emon', 'intvaw'): ('APmon', 'intvaw'),
#  ('Emon', 'jpdftaureicemodis'): ('APmon', 'jpdftaureicemodis'),
#  ('Emon', 'jpdftaureliqmodis'): ('APmon', 'jpdftaureliqmodis'),
#  ('Emon', 'loaddust'): ('APmon', 'loaddust'),
#  ('Emon', 'loadso4'): ('APmon', 'loadso4'),
#  ('Emon', 'loadss'): ('APmon', 'loadss'),
#  ('Emon', 'lwsrfasdust'): ('APmon', 'lwsrfasdust'),
#  ('Emon', 'lwsrfcsdust'): ('APmon', 'lwsrfcsdust'),
#  ('Emon', 'lwtoaasdust'): ('APmon', 'lwtoaasdust'),
#  ('Emon', 'lwtoacsaer'): ('APmon', 'lwtoacsaer'),
#  ('Emon', 'lwtoacsdust'): ('APmon', 'lwtoacsdust'),
#  ('Amon', 'n2o'): ('APmon', 'n2o'),
#  ('Amon', 'n2oglobal'): ('APmon', 'n2oglobal'),
#  ('Amon', 'o3'): ('APmon', 'o3'),
#  ('Emon', 'od443dust'): ('APmon', 'od443dust'),
#  ('Emon', 'od550aerso'): ('APmon', 'od550aerso'),
#  ('Emon', 'od550so4so'): ('APmon', 'od550so4so'),
#  ('Emon', 'od865dust'): ('APmon', 'od865dust'),
#  ('Emon', 'parasolRefl'): ('APmon', 'parasolRefl'),
#  ('CFmon', 'pctisccp'): ('APmon', 'pctisccp'),
#  ('Amon', 'pr'): ('APmon', 'pr'),
#  ('Emon', 'pr17O'): ('APmon', 'pr17O'),
#  ('Emon', 'pr18O'): ('APmon', 'pr18O'),
#  ('Emon', 'pr2h'): ('APmon', 'pr2h'),
#  ('Emon', 'prCrop'): ('APmon', 'prCrop'),
#  ('Amon', 'prc'): ('APmon', 'prc'),
#  ('Emon', 'prhmax'): ('APmon', 'prhmax'),
#  ('Omon', 'prra'): ('APmon', 'prra'),
#  ('Amon', 'prsn'): ('APmon', 'prsn'),
#  ('Emon', 'prsn17O'): ('APmon', 'prsn17O'),
#  ('Emon', 'prsn18O'): ('APmon', 'prsn18O'),
#  ('Emon', 'prsn2h'): ('APmon', 'prsn2h'),
#  ('Amon', 'prw'): ('APmon', 'prw'),
#  ('Amon', 'ps'): ('APmon', 'ps'),
#  ('Amon', 'psl'): ('APmon', 'psl'),
#  ('Emon', 'rainmxrat27'): ('APmon', 'rainmxrat27'),
#  ('Amon', 'rlds'): ('APmon', 'rlds'),
#  ('Amon', 'rldscs'): ('APmon', 'rldscs'),
#  ('Emon', 'rls'): ('APmon', 'rls'),
#  ('Amon', 'rlus'): ('APmon', 'rlus'),
#  ('Amon', 'rlut'): ('APmon', 'rlut'),
#  ('CFmon', 'rlut4co2'): ('APmon', 'rlut4co2'),
#  ('Amon', 'rlutcs'): ('APmon', 'rlutcs'),
#  ('CFmon', 'rlutcs4co2'): ('APmon', 'rlutcs4co2'),
#  ('Amon', 'rsds'): ('APmon', 'rsds'),
#  ('Amon', 'rsdscs'): ('APmon', 'rsdscs'),
#  ('Emon', 'rsdscsdiff'): ('APmon', 'rsdscsdiff'),
#  ('Emon', 'rsdsdiff'): ('APmon', 'rsdsdiff'),
#  ('Amon', 'rsdt'): ('APmon', 'rsdt'),
#  ('Emon', 'rss'): ('APmon', 'rss'),
#  ('Amon', 'rsus'): ('APmon', 'rsus'),
#  ('Amon', 'rsuscs'): ('APmon', 'rsuscs'),
#  ('Amon', 'rsut'): ('APmon', 'rsut'),
#  ('CFmon', 'rsut4co2'): ('APmon', 'rsut4co2'),
#  ('Amon', 'rsutcs'): ('APmon', 'rsutcs'),
#  ('CFmon', 'rsutcs4co2'): ('APmon', 'rsutcs4co2'),
#  ('Amon', 'rtmt'): ('APmon', 'rtmt'),
#  ('Amon', 'sci'): ('APmon', 'sci'),
#  ('Emon', 'sconcdust'): ('APmon', 'sconcdust'),
#  ('Emon', 'sconcso4'): ('APmon', 'sconcso4'),
#  ('Emon', 'sconcss'): ('APmon', 'sconcss'),
#  ('Amon', 'sfcWind'): ('APmon', 'sfcWind'),
#  ('Emon', 'sfcWindmax'): ('APmon', 'sfcWindmax'),
#  ('Emon', 'snowmxrat27'): ('APmon', 'snowmxrat27'),
#  ('Emon', 'swsrfasdust'): ('APmon', 'swsrfasdust'),
#  ('Emon', 'swsrfcsdust'): ('APmon', 'swsrfcsdust'),
#  ('Emon', 'swtoaasdust'): ('APmon', 'swtoaasdust'),
#  ('Emon', 'swtoacsdust'): ('APmon', 'swtoacsdust'),
#  ('Amon', 'ta'): ('APmon', 'ta'),
#  ('Emon', 'ta27'): ('APmon', 'ta27'),
#  ('Amon', 'tas'): ('APmon', 'tas'),
#  ('Amon', 'tasmax'): ('APmon', 'tasmax'),
#  ('Emon', 'tasmaxCrop'): ('APmon', 'tasmaxCrop'),
#  ('Amon', 'tasmin'): ('APmon', 'tasmin'),
#  ('Emon', 'tasminCrop'): ('APmon', 'tasminCrop'),
#  ('Amon', 'tauu'): ('APmon', 'tauu'),
#  ('Amon', 'tauv'): ('APmon', 'tauv'),
#  ('Emon', 'tdps'): ('APmon', 'tdps'),
#  ('Emon', 'tntmp27'): ('APmon', 'tntmp27'),
#  ('Amon', 'ts'): ('APmon', 'ts'),
#  ('Amon', 'ua'): ('APmon', 'ua19'),
#  ('Emon', 'ua27'): ('APmon', 'ua27'),
#  ('Emon', 'ua'): ('APmon', 'ua7h'),
#  ('Amon', 'uas'): ('APmon', 'uas'),
#  ('Emon', 'uqint'): ('APmon', 'uqint'),
#  ('Emon', 'utendnogw'): ('APmon', 'utendnogw'),
#  ('Emon', 'utendogw'): ('APmon', 'utendogw'),
#  ('Amon', 'va'): ('APmon', 'va19'),
#  ('Emon', 'va27'): ('APmon', 'va27'),
#  ('Emon', 'va'): ('APmon', 'va7h'),
#  ('Amon', 'vas'): ('APmon', 'vas'),
#  ('Emon', 'vqint'): ('APmon', 'vqint'),
#  ('Emon', 'vtendnogw'): ('APmon', 'vtendnogw'),
#  ('Emon', 'vtendogw'): ('APmon', 'vtendogw'),
#  ('Amon', 'wap'): ('APmon', 'wap'),
#  ('Amon', 'zg'): ('APmon', 'zg'),
#  ('Emon', 'zg27'): ('APmon', 'zg27'),
#  ('Amon', 'ch4Clim'): ('APmonClim', 'ch4Clim'),
#  ('Amon', 'ch4globalClim'): ('APmonClim', 'ch4globalClim'),
#  ('Amon', 'co2Clim'): ('APmonClim', 'co2Clim'),
#  ('Amon', 'co2massClim'): ('APmonClim', 'co2massClim'),
#  ('Amon', 'n2oClim'): ('APmonClim', 'n2oClim'),
#  ('Amon', 'n2oglobalClim'): ('APmonClim', 'n2oglobalClim'),
#  ('Amon', 'o3Clim'): ('APmonClim', 'o3Clim'),
#  ('Amon', 'pfull'): ('APmonClimLev', 'pfull'),
#  ('Amon', 'phalf'): ('APmonClimLev', 'phalf'),
#  ('E1hrClimMon', 'rlut'): ('APmonDiurnal', 'rlut'),
#  ('E1hrClimMon', 'rlutcs'): ('APmonDiurnal', 'rlutcs'),
#  ('E1hrClimMon', 'rsdt'): ('APmonDiurnal', 'rsdt'),
#  ('E1hrClimMon', 'rsut'): ('APmonDiurnal', 'rsut'),
#  ('E1hrClimMon', 'rsutcs'): ('APmonDiurnal', 'rsutcs'),
#  ('Amon', 'cl'): ('APmonLev', 'cl'),
#  ('CFmon', 'clc'): ('APmonLev', 'clc'),
#  ('Amon', 'cli'): ('APmonLev', 'cli'),
#  ('CFmon', 'clic'): ('APmonLev', 'clic'),
#  ('CFmon', 'clis'): ('APmonLev', 'clis'),
#  ('CFmon', 'cls'): ('APmonLev', 'cls'),
#  ('Amon', 'clw'): ('APmonLev', 'clw'),
#  ('CFmon', 'clwc'): ('APmonLev', 'clwc'),
#  ('CFmon', 'clws'): ('APmonLev', 'clws'),
#  ('Emon', 'co23D'): ('APmonLev', 'co23D'),
#  ('Emon', 'conccmcn'): ('APmonLev', 'conccmcn'),
#  ('Emon', 'conccn'): ('APmonLev', 'conccn'),
#  ('Emon', 'concdust'): ('APmonLev', 'concdust'),
#  ('Emon', 'concnmcn'): ('APmonLev', 'concnmcn'),
#  ('CFmon', 'dmc'): ('APmonLev', 'dmc'),
#  ('CFmon', 'edt'): ('APmonLev', 'edt'),
#  ('CFmon', 'evu'): ('APmonLev', 'evu'),
#  ('CFmon', 'hur'): ('APmonLev', 'hur'),
#  ('CFmon', 'hus'): ('APmonLev', 'hus'),
#  ('Amon', 'mc'): ('APmonLev', 'mc'),
#  ('CFmon', 'mcd'): ('APmonLev', 'mcd'),
#  ('CFmon', 'mcu'): ('APmonLev', 'mcu'),
#  ('Emon', 'md'): ('APmonLev', 'md'),
#  ('Emon', 'prw17O'): ('APmonLev', 'prw17O'),
#  ('Emon', 'prw2H'): ('APmonLev', 'prw2H'),
#  ('Emon', 'reffclic'): ('APmonLev', 'reffclic'),
#  ('Emon', 'reffclis'): ('APmonLev', 'reffclis'),
#  ('Emon', 'reffclwc'): ('APmonLev', 'reffclwc'),
#  ('Emon', 'reffclws'): ('APmonLev', 'reffclws'),
#  ('CFmon', 'rld'): ('APmonLev', 'rld'),
#  ('CFmon', 'rld4co2'): ('APmonLev', 'rld4co2'),
#  ('CFmon', 'rldcs'): ('APmonLev', 'rldcs'),
#  ('CFmon', 'rldcs4co2'): ('APmonLev', 'rldcs4co2'),
#  ('CFmon', 'rlu'): ('APmonLev', 'rlu'),
#  ('CFmon', 'rlu4co2'): ('APmonLev', 'rlu4co2'),
#  ('CFmon', 'rlucs'): ('APmonLev', 'rlucs'),
#  ('CFmon', 'rlucs4co2'): ('APmonLev', 'rlucs4co2'),
#  ('CFmon', 'rsd'): ('APmonLev', 'rsd'),
#  ('CFmon', 'rsd4co2'): ('APmonLev', 'rsd4co2'),
#  ('CFmon', 'rsdcs'): ('APmonLev', 'rsdcs'),
#  ('CFmon', 'rsdcs4co2'): ('APmonLev', 'rsdcs4co2'),
#  ('CFmon', 'rsu'): ('APmonLev', 'rsu'),
#  ('CFmon', 'rsu4co2'): ('APmonLev', 'rsu4co2'),
#  ('CFmon', 'rsucs'): ('APmonLev', 'rsucs'),
#  ('CFmon', 'rsucs4co2'): ('APmonLev', 'rsucs4co2'),
#  ('CFmon', 'smc'): ('APmonLev', 'smc'),
#  ('Emon', 't2'): ('APmonLev', 't2'),
#  ('CFmon', 'ta'): ('APmonLev', 'ta'),
#  ('CFmon', 'tnhus'): ('APmonLev', 'tnhus'),
#  ('CFmon', 'tnhusa'): ('APmonLev', 'tnhusa'),
#  ('CFmon', 'tnhusc'): ('APmonLev', 'tnhusc'),
#  ('CFmon', 'tnhusd'): ('APmonLev', 'tnhusd'),
#  ('CFmon', 'tnhusmp'): ('APmonLev', 'tnhusmp'),
#  ('Emon', 'tnhuspbl'): ('APmonLev', 'tnhuspbl'),
#  ('Emon', 'tnhusscp'): ('APmonLev', 'tnhusscp'),
#  ('CFmon', 'tnhusscpbl'): ('APmonLev', 'tnhusscpbl'),
#  ('CFmon', 'tnt'): ('APmonLev', 'tnt'),
#  ('CFmon', 'tnta'): ('APmonLev', 'tnta'),
#  ('CFmon', 'tntc'): ('APmonLev', 'tntc'),
#  ('Emon', 'tntd'): ('APmonLev', 'tntd'),
#  ('CFmon', 'tntmp'): ('APmonLev', 'tntmp'),
#  ('Emon', 'tntpbl'): ('APmonLev', 'tntpbl'),
#  ('CFmon', 'tntr'): ('APmonLev', 'tntr'),
#  ('Emon', 'tntrlcs'): ('APmonLev', 'tntrlcs'),
#  ('Emon', 'tntrscs'): ('APmonLev', 'tntrscs'),
#  ('Emon', 'tntscp'): ('APmonLev', 'tntscp'),
#  ('CFmon', 'tntscpbl'): ('APmonLev', 'tntscpbl'),
#  ('Emon', 'twap'): ('APmonLev', 'twap'),
#  ('Emon', 'u2'): ('APmonLev', 'u2'),
#  ('Emon', 'ut'): ('APmonLev', 'ut'),
#  ('Emon', 'uv'): ('APmonLev', 'uv'),
#  ('Emon', 'uwap'): ('APmonLev', 'uwap'),
#  ('Emon', 'v2'): ('APmonLev', 'v2'),
#  ('Emon', 'vt'): ('APmonLev', 'vt'),
#  ('Emon', 'vwap'): ('APmonLev', 'vwap'),
#  ('Emon', 'wap'): ('APmonLev', 'wap'),
#  ('Emon', 'wap2'): ('APmonLev', 'wap2'),
#  ('Emon', 'xgwdparam'): ('APmonLev', 'xgwdparam'),
#  ('Emon', 'ygwdparam'): ('APmonLev', 'ygwdparam'),
#  ('AERmon', 'zg'): ('APmonLev', 'zg'),
#  ('EmonZ', 'epfy'): ('APmonZ', 'epfy'),
#  ('EmonZ', 'epfz'): ('APmonZ', 'epfz'),
#  ('EmonZ', 'jo2'): ('APmonZ', 'jo2'),
#  ('EmonZ', 'jo3'): ('APmonZ', 'jo3'),
#  ('EmonZ', 'tntc'): ('APmonZ', 'tntc'),
#  ('EmonZ', 'tntmp'): ('APmonZ', 'tntmp'),
#  ('EmonZ', 'tntnogw'): ('APmonZ', 'tntnogw'),
#  ('EmonZ', 'tntogw'): ('APmonZ', 'tntogw'),
#  ('EmonZ', 'tntrlcs'): ('APmonZ', 'tntrlcs'),
#  ('EmonZ', 'tntrscs'): ('APmonZ', 'tntrscs'),
#  ('EmonZ', 'tntscp'): ('APmonZ', 'tntscp'),
#  ('EmonZ', 'utendepfd'): ('APmonZ', 'utendepfd'),
#  ('EmonZ', 'utendnogw'): ('APmonZ', 'utendnogw'),
#  ('EmonZ', 'vtem'): ('APmonZ', 'vtem'),
#  ('EmonZ', 'vtendnogw'): ('APmonZ', 'vtendnogw'),
#  ('EmonZ', 'wtem'): ('APmonZ', 'wtem'),
#  ('EmonZ', 'xgwdparam'): ('APmonZ', 'xgwdparam'),
#  ('EmonZ', 'ygwdparam'): ('APmonZ', 'ygwdparam'),
#  ('AERmonZ', 'zg'): ('APmonZ', 'zg'),
#  ('EmonZ', 'zmtnt'): ('APmonZ', 'zmtnt'),
#  ('Esubhr', 'hfls'): ('APsubhrPt', 'hfls'),
#  ('Esubhr', 'hfss'): ('APsubhrPt', 'hfss'),
#  ('Esubhr', 'huss'): ('APsubhrPt', 'huss'),
#  ('Esubhr', 'pr'): ('APsubhrPt', 'pr'),
#  ('Esubhr', 'prc'): ('APsubhrPt', 'prc'),
#  ('Esubhr', 'prw'): ('APsubhrPt', 'prw'),
#  ('Esubhr', 'ps'): ('APsubhrPt', 'ps'),
#  ('Esubhr', 'rlut'): ('APsubhrPt', 'rlut'),
#  ('Esubhr', 'rsdt'): ('APsubhrPt', 'rsdt'),
#  ('Esubhr', 'rsut'): ('APsubhrPt', 'rsut'),
#  ('Esubhr', 'tas'): ('APsubhrPt', 'tas'),
#  ('Esubhr', 'hus'): ('APsubhrPtLev', 'hus'),
#  ('Esubhr', 'mc'): ('APsubhrPtLev', 'mc'),
#  ('Esubhr', 'ta'): ('APsubhrPtLev', 'ta'),
#  ('Esubhr', 'tnhus'): ('APsubhrPtLev', 'tnhus'),
#  ('Esubhr', 'tnt'): ('APsubhrPtLev', 'tnt'),
#  ('Esubhr', 'ua'): ('APsubhrPtLev', 'ua'),
#  ('Esubhr', 'va'): ('APsubhrPtLev', 'va'),
#  ('Esubhr', 'wap'): ('APsubhrPtLev', 'wap'),
#  ('CFsubhr', 'ccb'): ('APsubhrPtSite', 'ccb'),
#  ('CFsubhr', 'cct'): ('APsubhrPtSite', 'cct'),
#  ('CFsubhr', 'ci'): ('APsubhrPtSite', 'ci'),
#  ('CFsubhr', 'cl'): ('APsubhrPtSite', 'cl'),
#  ('CFsubhr', 'cli'): ('APsubhrPtSite', 'cli'),
#  ('CFsubhr', 'clivi'): ('APsubhrPtSite', 'clivi'),
#  ('CFsubhr', 'clt'): ('APsubhrPtSite', 'clt'),
#  ('CFsubhr', 'clw'): ('APsubhrPtSite', 'clw'),
#  ('CFsubhr', 'clwvi'): ('APsubhrPtSite', 'clwvi'),
#  ('CFsubhr', 'edt'): ('APsubhrPtSite', 'edt'),
#  ('CFsubhr', 'evspsbl'): ('APsubhrPtSite', 'evspsbl'),
#  ('CFsubhr', 'evu'): ('APsubhrPtSite', 'evu'),
#  ('CFsubhr', 'fco2antt'): ('APsubhrPtSite', 'fco2antt'),
#  ('CFsubhr', 'fco2fos'): ('APsubhrPtSite', 'fco2fos'),
#  ('CFsubhr', 'fco2nat'): ('APsubhrPtSite', 'fco2nat'),
#  ('CFsubhr', 'hfls'): ('APsubhrPtSite', 'hfls'),
#  ('CFsubhr', 'hfss'): ('APsubhrPtSite', 'hfss'),
#  ('CFsubhr', 'hur'): ('APsubhrPtSite', 'hur'),
#  ('CFsubhr', 'hurs'): ('APsubhrPtSite', 'hurs'),
#  ('CFsubhr', 'hus'): ('APsubhrPtSite', 'hus'),
#  ('CFsubhr', 'huss'): ('APsubhrPtSite', 'huss'),
#  ('CFsubhr', 'mc'): ('APsubhrPtSite', 'mc'),
#  ('CFsubhr', 'pfull'): ('APsubhrPtSite', 'pfull'),
#  ('CFsubhr', 'phalf'): ('APsubhrPtSite', 'phalf'),
#  ('CFsubhr', 'pr'): ('APsubhrPtSite', 'pr'),
#  ('CFsubhr', 'prc'): ('APsubhrPtSite', 'prc'),
#  ('CFsubhr', 'prsn'): ('APsubhrPtSite', 'prsn'),
#  ('CFsubhr', 'prw'): ('APsubhrPtSite', 'prw'),
#  ('CFsubhr', 'ps'): ('APsubhrPtSite', 'ps'),
#  ('CFsubhr', 'psl'): ('APsubhrPtSite', 'psl'),
#  ('Esubhr', 'reffclic'): ('APsubhrPtSite', 'reffclic'),
#  ('Esubhr', 'reffclis'): ('APsubhrPtSite', 'reffclis'),
#  ('Esubhr', 'reffclwc'): ('APsubhrPtSite', 'reffclwc'),
#  ('Esubhr', 'reffclws'): ('APsubhrPtSite', 'reffclws'),
#  ('CFsubhr', 'rld'): ('APsubhrPtSite', 'rld'),
#  ('CFsubhr', 'rldcs'): ('APsubhrPtSite', 'rldcs'),
#  ('CFsubhr', 'rlds'): ('APsubhrPtSite', 'rlds'),
#  ('CFsubhr', 'rldscs'): ('APsubhrPtSite', 'rldscs'),
#  ('CFsubhr', 'rlu'): ('APsubhrPtSite', 'rlu'),
#  ('CFsubhr', 'rlucs'): ('APsubhrPtSite', 'rlucs'),
#  ('CFsubhr', 'rlus'): ('APsubhrPtSite', 'rlus'),
#  ('CFsubhr', 'rlut'): ('APsubhrPtSite', 'rlut'),
#  ('CFsubhr', 'rlutcs'): ('APsubhrPtSite', 'rlutcs'),
#  ('CFsubhr', 'rsd'): ('APsubhrPtSite', 'rsd'),
#  ('CFsubhr', 'rsdcs'): ('APsubhrPtSite', 'rsdcs'),
#  ('CFsubhr', 'rsds'): ('APsubhrPtSite', 'rsds'),
#  ('CFsubhr', 'rsdscs'): ('APsubhrPtSite', 'rsdscs'),
#  ('CFsubhr', 'rsdt'): ('APsubhrPtSite', 'rsdt'),
#  ('CFsubhr', 'rsu'): ('APsubhrPtSite', 'rsu'),
#  ('CFsubhr', 'rsucs'): ('APsubhrPtSite', 'rsucs'),
#  ('CFsubhr', 'rsus'): ('APsubhrPtSite', 'rsus'),
#  ('CFsubhr', 'rsuscs'): ('APsubhrPtSite', 'rsuscs'),
#  ('CFsubhr', 'rsut'): ('APsubhrPtSite', 'rsut'),
#  ('CFsubhr', 'rsutcs'): ('APsubhrPtSite', 'rsutcs'),
#  ('CFsubhr', 'rtmt'): ('APsubhrPtSite', 'rtmt'),
#  ('CFsubhr', 'sci'): ('APsubhrPtSite', 'sci'),
#  ('CFsubhr', 'sfcWind'): ('APsubhrPtSite', 'sfcWind'),
#  ('CFsubhr', 'ta'): ('APsubhrPtSite', 'ta'),
#  ('CFsubhr', 'tas'): ('APsubhrPtSite', 'tas'),
#  ('CFsubhr', 'tauu'): ('APsubhrPtSite', 'tauu'),
#  ('CFsubhr', 'tauv'): ('APsubhrPtSite', 'tauv'),
#  ('CFsubhr', 'tnhus'): ('APsubhrPtSite', 'tnhus'),
#  ('CFsubhr', 'tnhusa'): ('APsubhrPtSite', 'tnhusa'),
#  ('CFsubhr', 'tnhusc'): ('APsubhrPtSite', 'tnhusc'),
#  ('CFsubhr', 'tnhusd'): ('APsubhrPtSite', 'tnhusd'),
#  ('CFsubhr', 'tnhusmp'): ('APsubhrPtSite', 'tnhusmp'),
#  ('Esubhr', 'tnhuspbl'): ('APsubhrPtSite', 'tnhuspbl'),
#  ('Esubhr', 'tnhusscp'): ('APsubhrPtSite', 'tnhusscp'),
#  ('CFsubhr', 'tnhusscpbl'): ('APsubhrPtSite', 'tnhusscpbl'),
#  ('CFsubhr', 'tnt'): ('APsubhrPtSite', 'tnt'),
#  ('CFsubhr', 'tnta'): ('APsubhrPtSite', 'tnta'),
#  ('CFsubhr', 'tntc'): ('APsubhrPtSite', 'tntc'),
#  ('Esubhr', 'tntd'): ('APsubhrPtSite', 'tntd'),
#  ('CFsubhr', 'tntmp'): ('APsubhrPtSite', 'tntmp'),
#  ('Esubhr', 'tntpbl'): ('APsubhrPtSite', 'tntpbl'),
#  ('CFsubhr', 'tntr'): ('APsubhrPtSite', 'tntr'),
#  ('Esubhr', 'tntrlcs'): ('APsubhrPtSite', 'tntrlcs'),
#  ('Esubhr', 'tntrscs'): ('APsubhrPtSite', 'tntrscs'),
#  ('Esubhr', 'tntscp'): ('APsubhrPtSite', 'tntscp'),
#  ('CFsubhr', 'tntscpbl'): ('APsubhrPtSite', 'tntscpbl'),
#  ('CFsubhr', 'ts'): ('APsubhrPtSite', 'ts'),
#  ('CFsubhr', 'ua'): ('APsubhrPtSite', 'ua'),
#  ('CFsubhr', 'uas'): ('APsubhrPtSite', 'uas'),
#  ('CFsubhr', 'va'): ('APsubhrPtSite', 'va'),
#  ('CFsubhr', 'vas'): ('APsubhrPtSite', 'vas'),
#  ('CFsubhr', 'wap'): ('APsubhrPtSite', 'wap'),
#  ('CFsubhr', 'zg'): ('APsubhrPtSite', 'zg'),
#  ('IfxAnt', 'areacellg'): ('GIAfx', 'areacellg'),
#  ('IfxAnt', 'hfgeoubed'): ('GIAfx', 'hfgeoubed'),
#  ('IfxAnt', 'lithk'): ('GIAfx', 'lithk'),
#  ('IfxAnt', 'topg'): ('GIAfx', 'topg'),
#  ('ImonAnt', 'acabf'): ('GIAmon', 'acabf'),
#  ('ImonAnt', 'hfls'): ('GIAmon', 'hfls'),
#  ('ImonAnt', 'hfss'): ('GIAmon', 'hfss'),
#  ('ImonAnt', 'icem'): ('GIAmon', 'icem'),
#  ('ImonAnt', 'libmassbffl'): ('GIAmon', 'libmassbffl'),
#  ('ImonAnt', 'libmassbfgr'): ('GIAmon', 'libmassbfgr'),
#  ('ImonAnt', 'licalvf'): ('GIAmon', 'licalvf'),
#  ('ImonAnt', 'lifmassbf'): ('GIAmon', 'lifmassbf'),
#  ('ImonAnt', 'litempbotfl'): ('GIAmon', 'litempbotfl'),
#  ('ImonAnt', 'litempbotgr'): ('GIAmon', 'litempbotgr'),
#  ('ImonAnt', 'litemptop'): ('GIAmon', 'litemptop'),
#  ('ImonAnt', 'mrroLi'): ('GIAmon', 'mrroLi'),
#  ('ImonAnt', 'orog'): ('GIAmon', 'orog'),
#  ('ImonAnt', 'prra'): ('GIAmon', 'prra'),
#  ('ImonAnt', 'prsn'): ('GIAmon', 'prsn'),
#  ('ImonAnt', 'rlds'): ('GIAmon', 'rlds'),
#  ('ImonAnt', 'rlus'): ('GIAmon', 'rlus'),
#  ('ImonAnt', 'rsds'): ('GIAmon', 'rsds'),
#  ('ImonAnt', 'rsus'): ('GIAmon', 'rsus'),
#  ('ImonAnt', 'sbl'): ('GIAmon', 'sbl'),
#  ('ImonAnt', 'snc'): ('GIAmon', 'snc'),
#  ('ImonAnt', 'snicefreez'): ('GIAmon', 'snicefreez'),
#  ('ImonAnt', 'snicem'): ('GIAmon', 'snicem'),
#  ('ImonAnt', 'snm'): ('GIAmon', 'snm'),
#  ('ImonAnt', 'tas'): ('GIAmon', 'tas'),
#  ('ImonAnt', 'ts'): ('GIAmon', 'ts'),
#  ('ImonAnt', 'tsn'): ('GIAmon', 'tsn'),
#  ('IyrAnt', 'acabf'): ('GIAyr', 'acabf'),
#  ('IyrAnt', 'hfgeoubed'): ('GIAyr', 'hfgeoubed'),
#  ('IyrAnt', 'iareafl'): ('GIAyr', 'iareafl'),
#  ('IyrAnt', 'iareagr'): ('GIAyr', 'iareagr'),
#  ('IyrAnt', 'libmassbffl'): ('GIAyr', 'libmassbffl'),
#  ('IyrAnt', 'libmassbfgr'): ('GIAyr', 'libmassbfgr'),
#  ('IyrAnt', 'licalvf'): ('GIAyr', 'licalvf'),
#  ('IyrAnt', 'lifmassbf'): ('GIAyr', 'lifmassbf'),
#  ('IyrAnt', 'lim'): ('GIAyr', 'lim'),
#  ('IyrAnt', 'limnsw'): ('GIAyr', 'limnsw'),
#  ('IyrAnt', 'litempbotfl'): ('GIAyr', 'litempbotfl'),
#  ('IyrAnt', 'litempbotgr'): ('GIAyr', 'litempbotgr'),
#  ('IyrAnt', 'litemptop'): ('GIAyr', 'litemptop'),
#  ('IyrAnt', 'lithk'): ('GIAyr', 'lithk'),
#  ('IyrAnt', 'modelCellAreai'): ('GIAyr', 'modelCellAreai'),
#  ('IyrAnt', 'orog'): ('GIAyr', 'orog'),
#  ('IyrAnt', 'sftflf'): ('GIAyr', 'sftflf'),
#  ('IyrAnt', 'sftgif'): ('GIAyr', 'sftgif'),
#  ('IyrAnt', 'sftgrf'): ('GIAyr', 'sftgrf'),
#  ('IyrAnt', 'snc'): ('GIAyr', 'snc'),
#  ('IyrAnt', 'strbasemag'): ('GIAyr', 'strbasemag'),
#  ('IyrAnt', 'tendacabf'): ('GIAyr', 'tendacabf'),
#  ('IyrAnt', 'tendlibmassbf'): ('GIAyr', 'tendlibmassbf'),
#  ('IyrAnt', 'tendlicalvf'): ('GIAyr', 'tendlicalvf'),
#  ('IyrAnt', 'topg'): ('GIAyr', 'topg'),
#  ('IyrAnt', 'xvelbase'): ('GIAyr', 'xvelbase'),
#  ('IyrAnt', 'xvelmean'): ('GIAyr', 'xvelmean'),
#  ('IyrAnt', 'xvelsurf'): ('GIAyr', 'xvelsurf'),
#  ('IyrAnt', 'yvelbase'): ('GIAyr', 'yvelbase'),
#  ('IyrAnt', 'yvelmean'): ('GIAyr', 'yvelmean'),
#  ('IyrAnt', 'yvelsurf'): ('GIAyr', 'yvelsurf'),
#  ('IyrAnt', 'zvelbase'): ('GIAyr', 'zvelbase'),
#  ('IyrAnt', 'zvelsurf'): ('GIAyr', 'zvelsurf'),
#  ('IfxGre', 'areacellg'): ('GIGfx', 'areacellg'),
#  ('IfxGre', 'hfgeoubed'): ('GIGfx', 'hfgeoubed'),
#  ('IfxGre', 'lithk'): ('GIGfx', 'lithk'),
#  ('IfxGre', 'topg'): ('GIGfx', 'topg'),
#  ('ImonGre', 'acabf'): ('GIGmon', 'acabf'),
#  ('ImonGre', 'hfls'): ('GIGmon', 'hfls'),
#  ('ImonGre', 'hfss'): ('GIGmon', 'hfss'),
#  ('ImonGre', 'icem'): ('GIGmon', 'icem'),
#  ('ImonGre', 'libmassbffl'): ('GIGmon', 'libmassbffl'),
#  ('ImonGre', 'libmassbfgr'): ('GIGmon', 'libmassbfgr'),
#  ('ImonGre', 'licalvf'): ('GIGmon', 'licalvf'),
#  ('ImonGre', 'lifmassbf'): ('GIGmon', 'lifmassbf'),
#  ('ImonGre', 'litempbotfl'): ('GIGmon', 'litempbotfl'),
#  ('ImonGre', 'litempbotgr'): ('GIGmon', 'litempbotgr'),
#  ('ImonGre', 'litemptop'): ('GIGmon', 'litemptop'),
#  ('ImonGre', 'mrroLi'): ('GIGmon', 'mrroLi'),
#  ('ImonGre', 'orog'): ('GIGmon', 'orog'),
#  ...}
